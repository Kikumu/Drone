# %%
import random
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torchvision.transforms as T
from torch.nn.init import kaiming_uniform_
from torch.distributions import Normal
from scipy.ndimage.filters import uniform_filter1d
from matplotlib import pyplot as plt
from collections import namedtuple
from IPython.display import clear_output
from env.drone_env import DroneEnv
env = DroneEnv(render_mode="human", target_pos=[0.0, 0.0, 1.0])
import mlflow
import mlflow.pytorch
print(mlflow.get_tracking_uri())
# Out:
# C:\Users\ScottKikumu\AppData\Local\Temp\ipykernel_15696\3037674201.py:10: DeprecationWarning: Please import `uniform_filter1d` from the `scipy.ndimage` namespace; the `scipy.ndimage.filters` namespace is deprecated and will be removed in SciPy 2.0.0.
#   from scipy.ndimage.filters import uniform_filter1d
# sqlite:///C:/Users/ScottKikumu/Documents/AIP/Random/mlflow.db

# %%
import numpy as np
# import gym
from tqdm import tqdm
import random as rand
from itertools import count
import time
# import gym

# %%
class ReplayMemory():
    def __init__(self,capacity):   
        self.capacity = capacity
        self.memory = {}
        self.push_count = 0
        
    def push(self, timestep, experience):
        if len(self.memory) < self.capacity:
            self.memory[timestep] = experience
        else:
            del_key = None
            for k in self.memory.keys():
                del_key = k
                break
            self.memory.pop(del_key, None)
            self.memory[timestep] = experience
        self.push_count+=1
    
    def sample(self, batch_size):
        batch_tuple = random.sample(list(self.memory.items()), batch_size)#key(timestep), experiences
        experience_array = []
        for timestep, experiences in batch_tuple:
            experience_array.append(experiences)
        return experience_array
    
    def can_provide_sample(self, batch_size):
        return len(self.memory)>=batch_size
    
    def update_td_error(self, sampled_experiences, timesteps):
        for i in range(len(timesteps)):
            self.memory[timesteps[i]] = sampled_experiences[i]
        
    def get_memory_values(self):
        return self.memory

# %%
class Agent():
    def __init__(self, env, ReplayMemory, online_policy, online_q_a, online_q_b,\
                online_policy_optimizer,online_q_network_optimizer_a, online_q_network_optimizer_b, target_q_a,\
                target_q_b, gamma=0.99, alpha_pr=0.4, beta_pr=0.3,\
                tau=0.01, n_ep=120, max_steps=100000, memory_size=1000000, batch_size=20,\
                policy_update_step=2, target_update=50, min_sample_size=500, warm_up=2,\
                rank_based_prioritization=True, utd_ratio=4):
        
        
        self.env = env
        self.tau = tau
        self.gamma = gamma
        self.alpha_pr = alpha_pr
        self.beta_pr = beta_pr
        self.agent_max_memory=memory_size
        self.batch_size = batch_size
        self.n_ep = n_ep
        self.max_steps = max_steps
        self.min_sample_size=min_sample_size
        self.target_update=target_update
        self.policy_update_step=policy_update_step
        self.online_policy_network = online_policy
        self.online_policy_optimizer = online_policy_optimizer
        self.online_q_network_a = online_q_a
        self.online_q_network_optimizer_a = online_q_network_optimizer_a
        self.online_q_network_b = online_q_b
        self.online_q_network_optimizer_b = online_q_network_optimizer_b
        self.target_q_network_a = target_q_a
        self.target_q_network_b = target_q_b
        self.current_timestep = 0
        self.warm_up = warm_up
        self.agent_memory = ReplayMemory(self.agent_max_memory)
        self.device = torch.device("cuda" if torch.cuda.is_available()\
                        else "cpu")
        self.Xp = namedtuple('Experience',
                        ('state', 'action', 'next_state', 'reward', 'done', 'abs_td_error','timestep'))
        self.rank_based = rank_based_prioritization
        self.max_norm = 0.5
        self.utd_ratio = utd_ratio
        
    def extract_tensors(self, experiences):
        batch = self.Xp(*zip(*experiences))
        state = np.stack(batch.state) #stack
        action = np.stack(batch.action)
        next_state = np.stack(batch.next_state)
        reward = np.stack(batch.reward)
        done = np.stack(batch.done)
        abs_td_error = np.stack(batch.abs_td_error)
        timestep = np.stack(batch.timestep)
        return state,action,next_state,reward,done,abs_td_error,timestep
    
    def rebuild_experiences(self, state, action, next_state, reward, done, abs_error, timestep):
        exp_list = []
        for idx_ in range(len(state)):
            exp_list.append(\
                        self.Xp(state[idx_], action[idx_], next_state[idx_], reward[idx_],\
                           done[idx_], abs_error[idx_], timestep[idx_]))
        return exp_list 
    
    def prioritize_samples(self, experience_samples, alpha, beta,\
                           epsilon = 1e-6):
        state,action,next_state,reward,done,abs_td_error,timesteps \
                            = self.extract_tensors(experience_samples)
        
        if self.rank_based == True:
            abs_td_error, indices_ = (list(t) for t in zip(*sorted(\
                            zip(abs_td_error.tolist(), timesteps))))
            abs_td_error.reverse()
            indices_.reverse()#reverse to march sort func
            abs_td_error = np.array(abs_td_error)
            abs_td_error  = torch.tensor(abs_td_error)
            ranks = np.arange(1, len(abs_td_error)+1)
            priorities = 1.0/ranks
        else:
            priorities = abs_td_error + epsilon
            indices_ = None
        
        priorities = priorities**alpha
        priorities = np.expand_dims(priorities, axis=1)
        probabilities = priorities/np.sum(priorities, axis=0)
        assert np.isclose(probabilities.sum(), 1.0)
        number_of_samples  = len(probabilities)
        weight_importance_ = number_of_samples*probabilities
        weight_importance_ = weight_importance_**-beta
        weight_importance_max = np.max(weight_importance_)
        weight_importance_scaled = weight_importance_/weight_importance_max
        return weight_importance_scaled, indices_ 
    
    def update_model(self, experience_samples,\
                weighted_importance, timestep_indices):
        
        states, actions, next_states, rewards, done, _ , timesteps =\
                    self.extract_tensors(experience_samples)
        
        if self.rank_based == True:
            arrange_weighted_values = [timestep_indices.index(i) for i in timesteps]
        
        states = torch.tensor(np.squeeze(states)).float().to(self.device)
        next_states = torch.tensor(np.squeeze(next_states)).float().to(self.device)
        actions = torch.tensor(actions).float().to(self.device)
        rewards = torch.tensor(rewards).unsqueeze(1).float().to(self.device)
        done = torch.tensor(done).unsqueeze(1).float().to(self.device)
        weighted_importance = torch.tensor(weighted_importance).float().to(self.device)
    
        #optimize alpha
        current_actions,_, log_pi_s = self.online_policy_network.full_pass(states)
        target_alpha = (self.online_policy_network.target_entropy +\
                   log_pi_s).detach()
        alpha_loss = -(self.online_policy_network.log_alpha*\
                 target_alpha).mean()
        self.online_policy_network.target_entropy_optimizer.zero_grad()
        alpha_loss.backward()
        self.online_policy_network.target_entropy_optimizer.step()
    
        #set alpha
        alpha = self.online_policy_network.log_alpha.exp()
    
        #optimize online using target nets
        predicted_action_policy,_, log_pi_ns =\
                        self.online_policy_network.full_pass(next_states)

        qsa_target_a = self.target_q_network_a(next_states,\
                                        predicted_action_policy)
        qsa_target_b = self.target_q_network_b(next_states,\
                                        predicted_action_policy)
        target_qsa = torch.min(qsa_target_a, qsa_target_b)
        target_qsa = target_qsa - alpha*log_pi_ns
        target_qsa = rewards + self.gamma*target_qsa*(1 - done)
        #target_qsa = target_qsa*weighted_importance
        #print(weighted_importance)
        target_qsa = target_qsa.detach()
        qsa_online_a = self.online_q_network_a(states, actions)
        qsa_online_b = self.online_q_network_b(states, actions)
        
        #qsa_online_a = qsa_online_a*weighted_importance.detach()
        #qsa_online_b = qsa_online_b*weighted_importance.detach()
    
        #update online networks
        loss_func = torch.nn.SmoothL1Loss(reduction='none')
        qa_loss = (weighted_importance.detach() * loss_func(qsa_online_a,\
                            target_qsa.detach())).mean()
        qb_loss = (weighted_importance.detach() * loss_func(qsa_online_b,\
                            target_qsa.detach())).mean()
        if self.current_timestep%500 == 0:
            print(f"(Q_a loss:  {qa_loss.item():.4f}")
            print(f"(Q_b loss:  {qb_loss.item():.4f}")
            print(f"(Q_a values:  min={qsa_online_a.min().item():.4f} max={qsa_online_a.max().item():.4f}")
            print(f"(Targets Q:  min={target_qsa.min().item():.4f} max={target_qsa.max().item():.4f}")
            print(f"(alpha:  {self.online_policy_network.log_alpha.exp().item():.4f}")
            print(f"log_pi: {log_pi_s.mean().item():.4f}")
            print(f"target_entropy: {self.online_policy_network.target_entropy:.4f}")
            
            
        self.online_q_network_optimizer_a.zero_grad()
        qa_loss.backward()
        torch.nn.utils.clip_grad_norm_(self.online_q_network_a.parameters(), max_norm=self.max_norm)  # gradient clip
        self.online_q_network_optimizer_a.step()
    
        self.online_q_network_optimizer_b.zero_grad()
        qb_loss.backward()
        torch.nn.utils.clip_grad_norm_(self.online_q_network_b.parameters(), max_norm=self.max_norm)  # ← here
        self.online_q_network_optimizer_b.step()
    
        abs_a = (target_qsa.squeeze() - qsa_online_a.squeeze())
        abs_b = (target_qsa.squeeze() - qsa_online_b.squeeze())
        ovr_update = (abs_a + abs_b)/2
        ovr_update = abs(ovr_update.detach().cpu().numpy())
        if self.current_timestep % self.policy_update_step == 0:
            current_actions,_ , log_pi = self.online_policy_network.full_pass(states)

            #print(f"sum: {(self.online_policy_network.target_entropy + log_pi).mean().item():.4f}")
            #print(f"mean actions: {_.mean().item():.4f}")
            
            qsa_online_a = self.online_q_network_a(states, current_actions)
            qsa_online_b = self.online_q_network_b(states, current_actions)
            qsa_min = torch.min(qsa_online_a, qsa_online_b)
            policy_loss = (alpha*log_pi\
                      -qsa_min).mean()
            if self.current_timestep % 500 == 0:
                print(f"policy loss: {policy_loss.item():.4f}")
                print(f"sum: {(self.online_policy_network.target_entropy + log_pi).mean().item():.4f}")
                print(f"mean actions: {_.mean().item():.4f}")
                
            self.online_policy_optimizer.zero_grad()
            policy_loss.backward()
            if self.current_timestep % 500 == 0:
                print("before gradnorm")
                mean_layer_grad = self.online_policy_network.mean_layer.weight.grad
                dist_layer_grad = self.online_policy_network.distribution_layer.weight.grad
                input_layer_grad = self.online_policy_network.input_layer.weight.grad
    
                print(f"mean_layer grad norm:  {mean_layer_grad.norm().item():.6f}")
                print(f"dist_layer grad norm:  {dist_layer_grad.norm().item():.6f}")
                print(f"input_layer grad norm: {input_layer_grad.norm().item():.6f}")
                
            torch.nn.utils.clip_grad_norm_(self.online_policy_network.parameters(), max_norm=self.max_norm)  # ← here
            
            if self.current_timestep % 500 == 0:
                print("after gradnorm")
                mean_layer_grad = self.online_policy_network.mean_layer.weight.grad
                dist_layer_grad = self.online_policy_network.distribution_layer.weight.grad
                input_layer_grad = self.online_policy_network.input_layer.weight.grad
    
                print(f"mean_layer grad norm:  {mean_layer_grad.norm().item():.6f}")
                print(f"dist_layer grad norm:  {dist_layer_grad.norm().item():.6f}")
                print(f"input_layer grad norm: {input_layer_grad.norm().item():.6f}")

                with torch.no_grad():
                    test_state = torch.tensor([
                    0.0, 0.0, 0.5,    # pos — drone 0.5m up, target is 1m
                    0.0, 0.0, 0.0,    # vel
                    0.0, 0.0, 0.0,    # rpy
                    0.0, 0.0, 0.0,    # ang_vel
                    0.0, 0.0, 0.5,    # error — 0.5m below target
                    0.5,               # dist
                    0.5, 0.5, 0.5, 0.5
                    ], dtype=torch.float32).unsqueeze(0).to("cpu")
                    self.online_policy_network.eval()
                    test_mean, _ = self.online_policy_network.forward(test_state)
                    self.online_policy_network.train()
                    print(f"test_mean: {test_mean.detach().cpu().numpy()}")
                    
            #if self.current_timestep%100 == 0:
            mean_layer_grad = self.online_policy_network.mean_layer.weight.grad
            dist_layer_grad = self.online_policy_network.distribution_layer.weight.grad
            input_layer_grad = self.online_policy_network.input_layer.weight.grad
            
            metrics = {
            "q_a_loss":    qa_loss.item(),
            "q_b_loss":    qb_loss.item(),
            "alpha":       self.online_policy_network.log_alpha.exp().item(),
            "log_pi":      log_pi_s.mean().item(),
            "q_a_min":     qsa_online_a.min().item(),
            "q_a_max":     qsa_online_a.max().item(),
            "sum":         (self.online_policy_network.target_entropy + log_pi).mean().item(),
            "policy_loss": policy_loss.item(),
            "mean_layer_grad_norm": mean_layer_grad.norm().item(),
            "input_layer_grad_norm": input_layer_grad.norm().item(),
            "dist_layer_grad_norm": dist_layer_grad.norm().item()
            }
    
            self.online_policy_optimizer.step()
        states, actions, next_states, rewards, done, td_err , timesteps =\
                self.extract_tensors(experience_samples)    
        experiences_rebuilded = self.rebuild_experiences\
                (states, actions, next_states, rewards, done, ovr_update, timesteps)
        return experiences_rebuilded, timesteps, metrics
    
    def query_error(self, state, action, next_state, reward):

        state = torch.tensor(state).unsqueeze(0).float().to(self.device)
        next_state = torch.tensor(next_state).unsqueeze(0).float().to(self.device)
        #print("state -query_error: ", state.shape)
        #print("next_state -query_error: ", next_state.shape)
        alpha = self.online_policy_network.log_alpha.exp()
        self.online_policy_network.eval()
        self.target_q_network_a.eval()
        self.target_q_network_b.eval()
        ns_actions,_, log_pi_ns = self.online_policy_network.full_pass(next_state)
        
        q_target_next_states_action_a = self.target_q_network_a(next_state,\
                                                    ns_actions.detach())
        q_target_next_states_action_b = self.target_q_network_b(next_state,\
                                                    ns_actions.detach())
        self.online_policy_network.train()
        self.target_q_network_a.train()
        self.target_q_network_b.train()
        q_min = torch.min(q_target_next_states_action_a, q_target_next_states_action_b)
        q_target = q_min - alpha * log_pi_ns
        q_target = reward + (self.gamma*q_target.detach())
        action = np.expand_dims(action, axis=0)

        self.online_q_network_a.eval() #cause of batchnorm
        self.online_q_network_b.eval()
        q_online_state_action_val_a = self.online_q_network_a(state, action)
        q_online_state_action_val_b = self.online_q_network_b(state, action)
        self.online_q_network_a.train()
        self.online_q_network_b.train()
        
        abs_a = (q_target - q_online_state_action_val_a)
        abs_b = (q_target - q_online_state_action_val_b)
        abs_stack = (abs_a + abs_b)/2
        ovr_abs_update = abs_stack
        ovr_abs_update = ovr_abs_update.squeeze()
        return np.absolute(ovr_abs_update.detach().cpu().numpy())
    
    def select_action(self, state):
        #print("state: ", state)
        state = torch.tensor(state).float().to(self.device)
        state = state.unsqueeze(0)
        warm_up_action = self.batch_size
        if self.agent_memory.can_provide_sample(warm_up_action) == False:
            action = np.random.uniform(low=self.env.action_space.low,\
                                       high=self.env.action_space.high)
            action = action.reshape(self.env.action_space.high.shape)
        else:
            with torch.no_grad():
                self.online_policy_network.eval()
                mean,log_std = self.online_policy_network.forward(state)
                action = torch.tanh(Normal(mean, log_std.exp()).sample())
                action = self.online_policy_network.rescale_actions(action)
                action = action.detach().cpu().numpy().reshape(self.env.action_space.high.shape)
                self.online_policy_network.train()
                #print(f"mean: {mean.detach().cpu().numpy()}")
                #print(f"std:  {log_std.exp().detach().cpu().numpy()}")
                #print(f"action: {action}")
                #clear_output()
                #print("net option")
                #print("network actions:", action) 
        return action
    
    def update_targets(self, online_q_network_, target_q_network_, tau):
        for target_weights, online_weights in zip(target_q_network_.parameters(),\
                                                  online_q_network_.parameters()):
            target_weight_update = (1.0 - tau)*target_weights.data
            online_weight_update = tau*online_weights.data
            sum_up = target_weight_update + online_weight_update
            target_weights.data.copy_(sum_up)
        return target_q_network_
    
    def train(self):
        reward_per_ep = []
        
        for e in tqdm(range(self.n_ep)):
            state = self.env.reset()[0]
            prev_action = np.zeros(self.env.action_space.high.shape)
            # new_state
            state = np.concatenate([state, prev_action])
            #print("state shape -train : ", state.shape)
            reward_accumulated = 0
            while True:
                self.env.render()
                action = self.select_action(state)
                next_state, reward, done, truncated, info = self.env.step(action)
                # print("next state shape -train : ", next_state.shape)
                #reward = abs(reward)
                next_state = np.concatenate([next_state, action])
                # print("s: ", state.shape, " ns: ", next_state.shape)
                if done and not truncated:
                    reward -= 4 # reward penalty
                td_error = self.query_error(state, action, next_state, reward)
                
                reward_accumulated+=reward
                is_truncated = truncated
                is_failure = done and not is_truncated
                self.agent_memory.push(self.current_timestep,\
                            self.Xp(state, action, next_state,\
                            reward, is_failure, td_error, self.current_timestep))
                state = next_state
                if self.agent_memory.can_provide_sample(self.min_sample_size):
                    #print("sample size reached")
                    for _ in range(self.utd_ratio):
                        experience_samples = self.agent_memory.sample(self.batch_size)
                        weighted_importance, indices =\
                            self.prioritize_samples(experience_samples, self.alpha_pr, self.beta_pr)
                        experiences_rebuilded, timesteps, metrics = \
                            self.update_model(experience_samples, weighted_importance, indices)
                        self.agent_memory.update_td_error(experiences_rebuilded, timesteps)

                    
                        if self.current_timestep % self.target_update == 0:
                            self.target_q_network_a =\
                            self.update_targets(self.online_q_network_a,self.target_q_network_a, self.tau)
                            self.target_q_network_b =\
                            self.update_targets(self.online_q_network_b,self.target_q_network_b, self.tau)

                    if self.current_timestep %100 == 0:
                            mlflow.log_metrics(metrics, step=self.current_timestep)
                            save_checkpoint(self.online_q_network_a, self.online_q_network_b, self.online_policy_network, 
                            self.online_q_network_optimizer_a, self.online_q_network_optimizer_b, self.online_policy_optimizer, reward_per_ep)
                if done or truncated:
                        reward_per_ep.append(reward_accumulated)
                        # acc_.append(reward_accumulated)
                        if e % 100 == 0:
                            recent_avg = np.mean(reward_per_ep[-100:]) if len(reward_per_ep) >= 100 else np.mean(reward_per_ep)
                            print(f"ep {e} | avg reward (last 100): {recent_avg:.2f}")
                            mlflow.log_metric("avg_reward_100", recent_avg, step=e)
                            #save_checkpoint
                        #clear_output(wait=True)
                        #print(f"ep {e} | steps: {self.current_timestep} | reward: {reward_accumulated:.2f}")
                        break
                #if self.current_timestep > self.max_steps:
                        #reward_per_ep.append(reward_accumulated)
                        #self.env.close()
                        #break
                        #return reward_per_ep
                self.current_timestep+=1
        self.env.close()
        return reward_per_ep

# %%
class FCGP(nn.Module):
    def __init__(self,env, observation_space, action_space, hidden_dims=(32,32),\
                log_alpha_lr=0.000008, min_log= -20, max_log=2, dist_bias=-3.0):
        super(FCGP, self).__init__()
        self.input_size = observation_space
        self.env = env
        self.distribution_out = action_space
        self.mean_out = action_space
        self.log_alpha_lr = log_alpha_lr
        self.min_log = min_log
        self.max_log = max_log
        self.dist_bias = dist_bias
        self.input_layer = nn.Linear(self.input_size, hidden_dims[0])
        self.input_bn = nn.BatchNorm1d(self.input_size)
        self.hidden_layers = nn.ModuleList()
        #self.bn_layers = nn.ModuleList()
        for i in range(len(hidden_dims) - 1):
            #bn_layer = nn.BatchNorm1d(hidden_dims[i] + self.input_size)
            hidden_layer = nn.Linear(hidden_dims[i] + self.input_size,\
                                    hidden_dims[i+1])
            
            
            self.hidden_layers.append(hidden_layer)
            #self.bn_layers.append(bn_layer)

        #self.bn_mean_distr = nn.BatchNorm1d(hidden_dims[-1])
        
        self.mean_layer = nn.Linear(hidden_dims[-1], action_space)#predict mean
        self.distribution_layer = nn.Linear(hidden_dims[-1], action_space)#predict distribution
        nn.init.constant_(self.distribution_layer.bias, self.dist_bias)
        #nn.init.constant_(self.mean_layer.bias, -3.0)
        
        #self.target_entropy =  torch.tensor(-0.7).float()#moderate entropy - (-1 highly deterministic)
        self.target_entropy = -0.2 * torch.tensor(np.prod(env.action_space.high.shape)).float()
        self.log_alpha = torch.zeros(1, requires_grad=True)
        self.target_entropy_optimizer = torch.optim.Adam([self.log_alpha],\
                                                         lr=log_alpha_lr)
        self.device = torch.device("cuda" if torch.cuda.is_available()\
                                  else "cpu")
        self.to(self.device)
        
    def forward(self, state):
        if not isinstance(state, torch.Tensor):
            state = torch.tensor(state).float().to(self.device)
        x = self.input_bn(state)
        x = F.leaky_relu(self.input_layer(x))
        
        for i in range(len(self.hidden_layers)):
            x = torch.cat((x, state), dim=1)
            #x = self.bn_layers[i](x)
            x = F.leaky_relu(self.hidden_layers[i](x))
            
        #x = self.bn_mean_distr(x)
        mean_output = self.mean_layer(x)
        log_distribution_output = self.distribution_layer(x)
        
        log_distribution_output = log_distribution_output.clamp(self.min_log, self.max_log)#clamp log values so that they wont explode
        return mean_output, log_distribution_output
    
    def rescale_actions(self, x):
        tan_min = torch.tanh(torch.Tensor([float('-inf')])).to(self.device)
        tan_max = torch.tanh(torch.Tensor([float('inf')])).to(self.device)
        env_high = torch.tensor(self.env.action_space.high).float().to(self.device)
        env_low = torch.tensor(self.env.action_space.low).float().to(self.device)
        rescale_fn = lambda x: (x - tan_min) * (env_high - env_low)/\
                                     (tan_max - tan_min) + env_low
        x = rescale_fn(x)
        x = x.clamp(env_low, env_high)
        return x.to(self.device)
        
    
    def full_pass(self, state, epsilon=1e-6):
        if not isinstance(state, torch.Tensor):
            state = torch.tensor(state).float().to(self.device)
        #print("state -full_pass: ", state.shape)
        mean, log_distribution = self.forward(state)
        pi_s = Normal(mean, log_distribution.exp())
        sampled_distributions = pi_s.rsample()
        tan_h_actions = torch.tanh(sampled_distributions)
        
        rescaled_actions = self.rescale_actions(tan_h_actions)
        log_probs = pi_s.log_prob(sampled_distributions) - torch.log((\
                                                            1 - tan_h_actions.pow(2)).clamp(0,1) + epsilon)
        log_probs = log_probs.sum(dim=1, keepdim=True)
        #print("log distribution: ", log_distribution)
        return rescaled_actions, mean, log_probs

# %%
from torchsummary import summary

a = FCGP(env, 16, 4, hidden_dims=(256, 120, 120))
a.eval()
summary(a, input_size=(16,))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#        BatchNorm1d-1                   [-1, 16]              32
#             Linear-2                  [-1, 256]           4,352
#             Linear-3                  [-1, 120]          32,760
#             Linear-4                  [-1, 120]          16,440
#             Linear-5                    [-1, 4]             484
#             Linear-6                    [-1, 4]             484
# ================================================================
# Total params: 54,552
# Trainable params: 54,552
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.21
# Estimated Total Size (MB): 0.21
# ----------------------------------------------------------------

# %%
class FCQV(nn.Module):
    def __init__(self, observation_space, action_space, hidden_dims=(32,32), dropout_rate=0.01):
        super(FCQV, self).__init__()
        self.input_size = observation_space
        self.action_space = action_space
        self.input_layer = nn.Linear(self.input_size,\
                                    hidden_dims[0])
        self.input_bn = nn.BatchNorm1d(self.input_size)
        self.input_layer_norm = nn.LayerNorm(hidden_dims[0])
        self.hidden_layers = nn.ModuleList()
        #self.hidden_bn = nn.ModuleList()
        self.hidden_layer_norms = nn.ModuleList()
        self.hidden_layer_dropouts = nn.ModuleList()
        
        # now we have to bake in added action space TO EVERY hidden layer
        for i in range(len(hidden_dims)-1):
            hidden_layer = nn.Linear(hidden_dims[i] + action_space, hidden_dims[i+1])
            #bn_layer = nn.BatchNorm1d(hidden_dims[i] + action_space)
            norm_layer = nn.LayerNorm(hidden_dims[i+1])
            dropout_layer = nn.Dropout(p=dropout_rate)
            self.hidden_layers.append(hidden_layer)
            self.hidden_layer_norms.append(norm_layer)
            self.hidden_layer_dropouts.append(dropout_layer)
            #self.hidden_bn.append(bn_layer)

        #self.output_batch_norm = nn.BatchNorm1d(hidden_dims[-1])
        self.output_layer = nn.Linear(hidden_dims[-1], 1)
        self.device = torch.device("cuda" if torch.cuda.is_available()\
                                  else "cpu")
        self.to(self.device)
        
    def forward(self, state, action):
        if not isinstance(state, torch.Tensor):
            state = torch.tensor(state).float().to(self.device)
        if not isinstance(action, torch.Tensor):
            action = torch.tensor(action).float().to(self.device)
        #x = torch.cat((state, action), dim=1)
        x = self.input_bn(state) # normalise state
        x = self.input_layer(x)
        x = self.input_layer_norm(x)
        x = F.leaky_relu(x)
        # x = self.input_bn(x)
        for i in range(len(self.hidden_layers)):
            x = torch.cat((x, action), dim=1)
            #x = self.hidden_bn[i](x) # normalise
            x = self.hidden_layers[i](x)
            x = self.hidden_layer_norms[i](x)
            x = F.leaky_relu(x)
            x = self.hidden_layer_dropouts[i](x)
        #x = self.output_batch_norm(x)
        x = self.output_layer(x) 
        return x

# %%
a = FCQV(16, 4, hidden_dims=(256, 256, 256))
a.eval()
summary(a, input_size=[(16,), (4,)])
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#        BatchNorm1d-1                   [-1, 16]              32
#             Linear-2                  [-1, 256]           4,352
#          LayerNorm-3                  [-1, 256]             512
#             Linear-4                  [-1, 256]          66,816
#          LayerNorm-5                  [-1, 256]             512
#            Dropout-6                  [-1, 256]               0
#             Linear-7                  [-1, 256]          66,816
#          LayerNorm-8                  [-1, 256]             512
#            Dropout-9                  [-1, 256]               0
#            Linear-10                    [-1, 1]             257
# ================================================================
# Total params: 139,809
# Trainable params: 139,809
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.02
# Params size (MB): 0.53
# Estimated Total Size (MB): 0.55
# ----------------------------------------------------------------

# %%
def plot_grad_flow(named_parameters):
    ave_grads = []
    layers = []
    for n, p in named_parameters:
        if(p.requires_grad) and ("bias" not in n):
            layers.append(n)
            ave_grads.append(p.grad.abs().mean().detach().cpu().numpy())
    plt.plot(ave_grads, alpha=0.3, color="b")
    plt.hlines(0, 0, len(ave_grads)+1, linewidth=1, color="k" )
    plt.xticks(range(0,len(ave_grads), 1), layers, rotation="vertical")
    plt.xlim(xmin=0, xmax=len(ave_grads))
    plt.xlabel("Layers")
    plt.ylabel("average gradient")
    plt.title("Gradient flow")
    plt.grid(True)

# %%
def copy_network(online_network, target_network):
    for online_weights, target_weights in zip(online_network.parameters(),\
                                              target_network.parameters()):
        target_weights.data.copy_(online_weights.data)
    return target_network

# %%
def SAC_PER(env, resume=True):
    
    mlflow.set_experiment("SAC-Drone-Hover")
    
    gamma__ = 0.88
    tau__ = 0.05
    lr_policy__ = 0.000008
    lr_q__ = 0.000003
    lr_q1__ = 0.000003
    batch_size__ = 64
    min_sample_size__ = 1000
    target_update__ = 1
    memory_size__ = 200000
    min_log__ = -20
    max_log__ = 2
    dist_bias_init__ = -3.0
    max_norm__ = 0.5
    alpha_pr__ = 0.4
    beta_pr__ = 0.6
    n_ep__ = 10000
    policy_update_step__ = 1
    log_alpha_lr__ = 0.000008
    min_log__ = -20
    max_log__ = 2
    dist_bias__ = -3.0
    utd_ratio__ = 4
    
    
    with mlflow.start_run():
        
        observation_space = len(env.reset()[0])
        action_space_high, action_space_low = env.action_space.high, env.action_space.low
        n_actions = len(action_space_high)
    
        # augment_obs space
        observation_space = len(env.reset()[0]) + n_actions
        online_policy_network = FCGP(env,observation_space,n_actions,\
                                         hidden_dims=(256,256,128),\
                                         log_alpha_lr = log_alpha_lr__,
                                         min_log = min_log__,
                                         max_log = max_log__,
                                         dist_bias = dist_bias__
                                    )
        #print(online_policy_network)
        
        online_q_network_a = FCQV(observation_space,\
                                         n_actions,hidden_dims=(256,256))
        online_q_network_b = FCQV(observation_space,\
                                         n_actions,hidden_dims=(256,256))
        
        target_q_network_a = FCQV(observation_space,\
                                         n_actions,hidden_dims=(256,256))
        target_q_network_b = FCQV(observation_space,\
                                         n_actions,hidden_dims=(256,256))
        
        #copy parameters from online to target
        target_q_network_a = copy_network(online_q_network_a, target_q_network_a)
        target_q_network_b = copy_network(online_q_network_b, target_q_network_b)

        online_policy_optimizer = torch.optim.Adam(online_policy_network.parameters(),lr=lr_policy__)
        online_qa_network_optimizer = torch.optim.Adam(online_q_network_a.parameters(),lr=lr_q__)
        online_qb_network_optimizer = torch.optim.Adam(online_q_network_b.parameters(),lr=lr_q1__)
    
        prior_rewards = []
        if resume:
            prior_rewards = load_checkpoint(
                online_q_network_a, online_q_network_b, online_policy_network,
                online_qa_network_optimizer, online_qb_network_optimizer, online_policy_optimizer, target_q_network_a, target_q_network_b
            )
            # also copy loaded weights to target networks
            target_q_network_a = copy_network(online_q_network_a, target_q_network_a)
            target_q_network_b = copy_network(online_q_network_b, target_q_network_b)
        
        target_q_network_a.eval()
        target_q_network_b.eval()

        
        
        

        
        
        agent = Agent(env, ReplayMemory, online_policy_network, online_q_network_a, online_q_network_b,\
                    online_policy_optimizer,online_qa_network_optimizer, online_qb_network_optimizer, target_q_network_a,\
                    target_q_network_b, gamma=gamma__, alpha_pr=alpha_pr__, beta_pr=beta_pr__,\
                    tau=tau__, n_ep=n_ep__, max_steps=1000000, memory_size=memory_size__, batch_size=batch_size__,\
                    policy_update_step=policy_update_step__, target_update=target_update__, min_sample_size=min_sample_size__,\
                    warm_up=5, rank_based_prioritization=True, utd_ratio = utd_ratio__)
        
        rewards = agent.train() 
        return rewards, online_q_network_a, online_q_network_b,\
        online_policy_network, online_qa_network_optimizer,\
        online_qb_network_optimizer, online_policy_optimizer

# %%
import os
import torch

def save_checkpoint(online_q_a, online_q_b, online_policy, 
                    qa_optimizer, qb_optimizer, policy_optimizer, rewards, path='checkpoints'):
    os.makedirs(path, exist_ok=True)
    torch.save(online_q_a.state_dict(),     f'{path}/online_q_a.pth')
    torch.save(online_q_b.state_dict(),     f'{path}/online_q_b.pth')
    torch.save(online_policy.state_dict(),  f'{path}/online_policy.pth')
    torch.save(qa_optimizer.state_dict(),   f'{path}/qa_optimizer.pth')
    torch.save(qb_optimizer.state_dict(),   f'{path}/qb_optimizer.pth')
    torch.save(policy_optimizer.state_dict(), f'{path}/policy_optimizer.pth')
    torch.save(online_policy.target_entropy_optimizer.state_dict(), f'{path}/alpha_opt.pth')
    torch.save({
        'rewards': rewards,
        'log_alpha': online_policy.log_alpha.item(),
        'target_entropy': online_policy.target_entropy
    }, f'{path}/training_state.pth')
    print(f"Saved checkpoint to {path}/")

# %%
def load_checkpoint(online_q_a, online_q_b, online_policy,
                    qa_opt, qb_opt, policy_opt,
                    target_q_a, target_q_b,
                    path='checkpoints'):
    online_q_a.load_state_dict(torch.load(f'{path}/online_q_a.pth'))
    online_q_b.load_state_dict(torch.load(f'{path}/online_q_b.pth'))
    online_policy.load_state_dict(torch.load(f'{path}/online_policy.pth'))
    qa_opt.load_state_dict(torch.load(f'{path}/qa_optimizer.pth'))
    qb_opt.load_state_dict(torch.load(f'{path}/qb_optimizer.pth'))
    policy_opt.load_state_dict(torch.load(f'{path}/policy_optimizer.pth'))
    online_policy.target_entropy_optimizer.load_state_dict(
        torch.load(f'{path}/alpha_opt.pth'))

    state = torch.load(f'{path}/training_state.pth')
    with torch.no_grad():
        online_policy.log_alpha.fill_(state['log_alpha'])

    copy_network(online_q_a, target_q_a)
    copy_network(online_q_b, target_q_b)

    print(f"Loaded from {path}/ | log_alpha={state['log_alpha']:.4f}")
    return state['rewards']

# %%
rewards,a,b,c,d,e,f = SAC_PER(env, resume=True)
# Out:
# Loaded from checkpoints/ | log_alpha=-0.0145
#   0%|                                                                                | 1/10000 [00:00<52:42,  3.16it/s]
# ep 0 | avg reward (last 100): 26.20
#   1%|▍                                                                              | 55/10000 [00:15<53:43,  3.09it/s]
# (Q_a loss:  1.8206
# (Q_b loss:  2.1381
# (Q_a values:  min=4.4983 max=5.6401
# (Targets Q:  min=-11.6179 max=10.8046
# (alpha:  0.9856
# log_pi: -1.8678
# target_entropy: -0.8000
# policy loss: -6.3475
# sum: -2.4604
# mean actions: 0.0047
# before gradnorm
# mean_layer grad norm:  2.092363
# dist_layer grad norm:  4.292097
# input_layer grad norm: 0.961187
# after gradnorm
# mean_layer grad norm:  0.181955
# dist_layer grad norm:  0.373248
# input_layer grad norm: 0.083586
# test_mean: [[-0.03016349  0.00083807  0.00413806 -0.01808311]]
# (Q_a loss:  1.6567
# (Q_b loss:  1.9592
# (Q_a values:  min=4.6979 max=5.6564
# (Targets Q:  min=-11.7482 max=10.0464
# (alpha:  0.9856
# log_pi: -1.2409
# target_entropy: -0.8000
# policy loss: -6.0770
# sum: -2.1869
# mean actions: 0.0028
# before gradnorm
# mean_layer grad norm:  3.478708
# dist_layer grad norm:  6.242543
# input_layer grad norm: 2.029420
# after gradnorm
# mean_layer grad norm:  0.190928
# dist_layer grad norm:  0.342621
# input_layer grad norm: 0.111384
# test_mean: [[-0.03179244  0.00079789  0.00511088 -0.01880522]]
# (Q_a loss:  2.1028
# (Q_b loss:  2.4204
# (Q_a values:  min=4.5430 max=5.8058
# (Targets Q:  min=-13.9286 max=9.6629
# (alpha:  0.9855
# log_pi: -0.6518
# target_entropy: -0.8000
# policy loss: -5.7253
# sum: -1.7951
# mean actions: 0.0021
# before gradnorm
# mean_layer grad norm:  1.781667
# dist_layer grad norm:  3.777855
# input_layer grad norm: 2.310487
# after gradnorm
# mean_layer grad norm:  0.139540
# dist_layer grad norm:  0.295881
# input_layer grad norm: 0.180957
# test_mean: [[-0.03277342  0.0004144   0.00674037 -0.0203043 ]]
# (Q_a loss:  1.9307
# (Q_b loss:  2.2592
# (Q_a values:  min=4.6802 max=5.7687
# (Targets Q:  min=-19.9016 max=10.4680
# (alpha:  0.9855
# log_pi: -1.4534
# target_entropy: -0.8000
# policy loss: -6.4815
# sum: -2.5648
# mean actions: 0.0032
# before gradnorm
# mean_layer grad norm:  1.957076
# dist_layer grad norm:  3.647308
# input_layer grad norm: 1.529993
# after gradnorm
# mean_layer grad norm:  0.167539
# dist_layer grad norm:  0.312235
# input_layer grad norm: 0.130978
# test_mean: [[-0.03093945 -0.00042838  0.00709446 -0.01836672]]
# Saved checkpoint to checkpoints/
#   1%|▍                                                                            | 59/10000 [00:26<5:01:46,  1.82s/it]
# Saved checkpoint to checkpoints/
#   1%|▍                                                                            | 64/10000 [00:36<5:09:23,  1.87s/it]
# Saved checkpoint to checkpoints/
#   1%|▌                                                                            | 70/10000 [00:54<7:09:45,  2.60s/it]
# Saved checkpoint to checkpoints/
#   1%|▌                                                                            | 76/10000 [01:08<6:06:25,  2.22s/it]
# Saved checkpoint to checkpoints/
#   1%|▌                                                                            | 81/10000 [01:21<6:58:59,  2.53s/it]
# (Q_a loss:  1.5132
# (Q_b loss:  1.8865
# (Q_a values:  min=6.6732 max=7.3236
# (Targets Q:  min=6.4415 max=11.6082
# (alpha:  0.9682
# log_pi: -2.5813
# target_entropy: -0.8000
# policy loss: -9.0870
# sum: -3.4622
# mean actions: 0.0066
# before gradnorm
# mean_layer grad norm:  2.146476
# dist_layer grad norm:  3.752828
# input_layer grad norm: 0.623296
# after gradnorm
# mean_layer grad norm:  0.208421
# dist_layer grad norm:  0.364396
# input_layer grad norm: 0.060522
# test_mean: [[-0.02202884 -0.00315885  0.01271575 -0.01755782]]
# (Q_a loss:  1.6560
# (Q_b loss:  2.0466
# (Q_a values:  min=6.6258 max=7.3264
# (Targets Q:  min=6.7137 max=12.0677
# (alpha:  0.9682
# log_pi: -2.6050
# target_entropy: -0.8000
# policy loss: -9.0097
# sum: -3.3602
# mean actions: 0.0052
# before gradnorm
# mean_layer grad norm:  2.438528
# dist_layer grad norm:  4.008446
# input_layer grad norm: 0.732985
# after gradnorm
# mean_layer grad norm:  0.220740
# dist_layer grad norm:  0.362851
# input_layer grad norm: 0.066351
# test_mean: [[-0.02109606 -0.00574047  0.0132194  -0.01946486]]
# (Q_a loss:  1.5977
# (Q_b loss:  1.9687
# (Q_a values:  min=6.6246 max=7.3449
# (Targets Q:  min=6.6940 max=10.8857
# (alpha:  0.9682
# log_pi: -2.6964
# target_entropy: -0.8000
# policy loss: -9.0974
# sum: -3.4412
# mean actions: 0.0047
# before gradnorm
# mean_layer grad norm:  3.078602
# dist_layer grad norm:  2.988471
# input_layer grad norm: 0.639773
# after gradnorm
# mean_layer grad norm:  0.310224
# dist_layer grad norm:  0.301142
# input_layer grad norm: 0.064469
# test_mean: [[-0.02296914 -0.00548223  0.01124665 -0.01830565]]
# (Q_a loss:  1.6526
# (Q_b loss:  2.1121
# (Q_a values:  min=6.6834 max=7.3184
# (Targets Q:  min=6.9426 max=11.7997
# (alpha:  0.9682
# log_pi: -2.6640
# target_entropy: -0.8000
# policy loss: -9.0085
# sum: -3.3667
# mean actions: 0.0028
# before gradnorm
# mean_layer grad norm:  4.296474
# dist_layer grad norm:  3.542187
# input_layer grad norm: 0.865449
# after gradnorm
# mean_layer grad norm:  0.333900
# dist_layer grad norm:  0.275281
# input_layer grad norm: 0.067258
# test_mean: [[-0.02064166 -0.0018154   0.01156433 -0.01881064]]
# Saved checkpoint to checkpoints/
#   1%|▋                                                                            | 89/10000 [01:35<4:57:48,  1.80s/it]
# Saved checkpoint to checkpoints/
#   1%|▋                                                                            | 96/10000 [01:50<5:13:08,  1.90s/it]
# Saved checkpoint to checkpoints/
#   1%|▊                                                                           | 101/10000 [02:02<6:02:16,  2.20s/it]
# ep 100 | avg reward (last 100): 25.19
#   1%|▊                                                                           | 102/10000 [02:03<5:31:33,  2.01s/it]
# Saved checkpoint to checkpoints/
#   1%|▊                                                                           | 107/10000 [02:17<7:59:50,  2.91s/it]
# Saved checkpoint to checkpoints/
#   1%|▊                                                                           | 112/10000 [02:28<6:33:38,  2.39s/it]
# (Q_a loss:  1.5722
# (Q_b loss:  1.9994
# (Q_a values:  min=7.9294 max=8.4071
# (Targets Q:  min=7.9653 max=12.6251
# (alpha:  0.9515
# log_pi: -2.6563
# target_entropy: -0.8000
# policy loss: -10.3218
# sum: -3.5712
# mean actions: 0.0075
# before gradnorm
# mean_layer grad norm:  3.017345
# dist_layer grad norm:  2.738998
# input_layer grad norm: 0.738465
# after gradnorm
# mean_layer grad norm:  0.318442
# dist_layer grad norm:  0.289066
# input_layer grad norm: 0.077935
# test_mean: [[-0.02489801  0.0191726   0.00773248 -0.01604879]]
# (Q_a loss:  1.6015
# (Q_b loss:  2.0275
# (Q_a values:  min=7.9080 max=8.3885
# (Targets Q:  min=7.5626 max=13.2125
# (alpha:  0.9515
# log_pi: -2.6735
# target_entropy: -0.8000
# policy loss: -10.1997
# sum: -3.4544
# mean actions: 0.0085
# before gradnorm
# mean_layer grad norm:  2.165532
# dist_layer grad norm:  1.535769
# input_layer grad norm: 0.805500
# after gradnorm
# mean_layer grad norm:  0.288936
# dist_layer grad norm:  0.204910
# input_layer grad norm: 0.107474
# test_mean: [[-0.02541984  0.01741831  0.00735079 -0.01488587]]
# (Q_a loss:  1.4972
# (Q_b loss:  1.9287
# (Q_a values:  min=7.8537 max=8.4060
# (Targets Q:  min=7.9293 max=12.6281
# (alpha:  0.9515
# log_pi: -2.6196
# target_entropy: -0.8000
# policy loss: -10.1992
# sum: -3.4273
# mean actions: 0.0082
# before gradnorm
# mean_layer grad norm:  3.268421
# dist_layer grad norm:  2.520399
# input_layer grad norm: 0.863912
# after gradnorm
# mean_layer grad norm:  0.325251
# dist_layer grad norm:  0.250813
# input_layer grad norm: 0.085971
# test_mean: [[-0.02603843  0.01575093  0.00767007 -0.01355888]]
# (Q_a loss:  1.4229
# (Q_b loss:  1.8179
# (Q_a values:  min=7.8591 max=8.3564
# (Targets Q:  min=6.0386 max=12.7129
# (alpha:  0.9515
# log_pi: -2.7172
# target_entropy: -0.8000
# policy loss: -10.2481
# sum: -3.4978
# mean actions: 0.0080
# before gradnorm
# mean_layer grad norm:  2.352808
# dist_layer grad norm:  1.878612
# input_layer grad norm: 0.731620
# after gradnorm
# mean_layer grad norm:  0.305650
# dist_layer grad norm:  0.244048
# input_layer grad norm: 0.095044
# test_mean: [[-0.02716316  0.01468831  0.00731707 -0.01172213]]
# Saved checkpoint to checkpoints/
#   1%|▉                                                                           | 120/10000 [02:44<5:16:06,  1.92s/it]
# Saved checkpoint to checkpoints/
#   1%|▉                                                                           | 125/10000 [02:55<6:28:49,  2.36s/it]
# Saved checkpoint to checkpoints/
#   1%|▉                                                                           | 131/10000 [03:11<6:34:13,  2.40s/it]
# Saved checkpoint to checkpoints/
#   1%|█                                                                           | 138/10000 [03:26<6:19:14,  2.31s/it]
# Saved checkpoint to checkpoints/
#   1%|█                                                                           | 145/10000 [03:41<5:52:41,  2.15s/it]
# (Q_a loss:  1.4698
# (Q_b loss:  1.8660
# (Q_a values:  min=8.9750 max=9.4183
# (Targets Q:  min=8.0123 max=13.2978
# (alpha:  0.9353
# log_pi: -2.7095
# target_entropy: -0.8000
# policy loss: -11.2435
# sum: -3.5230
# mean actions: 0.0091
# before gradnorm
# mean_layer grad norm:  2.343822
# dist_layer grad norm:  2.821613
# input_layer grad norm: 0.533295
# after gradnorm
# mean_layer grad norm:  0.262193
# dist_layer grad norm:  0.315641
# input_layer grad norm: 0.059657
# test_mean: [[-0.02676078  0.02031094  0.01677355 -0.00391604]]
# (Q_a loss:  1.4702
# (Q_b loss:  1.8821
# (Q_a values:  min=8.8205 max=9.4257
# (Targets Q:  min=9.0478 max=13.3833
# (alpha:  0.9353
# log_pi: -2.6833
# target_entropy: -0.8000
# policy loss: -11.1614
# sum: -3.4222
# mean actions: 0.0096
# before gradnorm
# mean_layer grad norm:  3.591608
# dist_layer grad norm:  3.154932
# input_layer grad norm: 0.752274
# after gradnorm
# mean_layer grad norm:  0.311893
# dist_layer grad norm:  0.273972
# input_layer grad norm: 0.065327
# test_mean: [[-0.02498718  0.01903717  0.0154819  -0.00317961]]
# (Q_a loss:  1.4896
# (Q_b loss:  1.9143
# (Q_a values:  min=8.5088 max=9.4136
# (Targets Q:  min=8.5555 max=14.1788
# (alpha:  0.9353
# log_pi: -2.6984
# target_entropy: -0.8000
# policy loss: -11.2523
# sum: -3.5253
# mean actions: 0.0072
# before gradnorm
# mean_layer grad norm:  2.716348
# dist_layer grad norm:  2.718422
# input_layer grad norm: 0.797699
# after gradnorm
# mean_layer grad norm:  0.297404
# dist_layer grad norm:  0.297631
# input_layer grad norm: 0.087337
# test_mean: [[-0.02532046  0.01903935  0.01549309 -0.00295845]]
# (Q_a loss:  1.4373
# (Q_b loss:  1.8656
# (Q_a values:  min=8.9595 max=9.4256
# (Targets Q:  min=8.6542 max=13.0857
# (alpha:  0.9353
# log_pi: -2.7101
# target_entropy: -0.8000
# policy loss: -11.2531
# sum: -3.5291
# mean actions: 0.0045
# before gradnorm
# mean_layer grad norm:  2.564032
# dist_layer grad norm:  3.346930
# input_layer grad norm: 0.929446
# after gradnorm
# mean_layer grad norm:  0.254467
# dist_layer grad norm:  0.332165
# input_layer grad norm: 0.092243
# test_mean: [[-0.02472238  0.01705294  0.01655194 -0.00465827]]
# Saved checkpoint to checkpoints/
#   2%|█▏                                                                          | 152/10000 [03:55<5:31:36,  2.02s/it]
# Saved checkpoint to checkpoints/
#   2%|█▏                                                                          | 159/10000 [04:11<5:25:32,  1.98s/it]
# Saved checkpoint to checkpoints/
#   2%|█▎                                                                          | 168/10000 [04:27<4:12:22,  1.54s/it]
# Saved checkpoint to checkpoints/
#   2%|█▎                                                                          | 174/10000 [04:41<5:53:06,  2.16s/it]
# Saved checkpoint to checkpoints/
#   2%|█▎                                                                          | 179/10000 [04:55<8:12:55,  3.01s/it]
# (Q_a loss:  1.2189
# (Q_b loss:  1.6088
# (Q_a values:  min=9.8864 max=10.4052
# (Targets Q:  min=9.5345 max=14.1911
# (alpha:  0.9194
# log_pi: -2.6701
# target_entropy: -0.8000
# policy loss: -12.1763
# sum: -3.5259
# mean actions: 0.0020
# before gradnorm
# mean_layer grad norm:  2.759614
# dist_layer grad norm:  2.870513
# input_layer grad norm: 0.578227
# after gradnorm
# mean_layer grad norm:  0.298942
# dist_layer grad norm:  0.310955
# input_layer grad norm: 0.062638
# test_mean: [[-0.01419573  0.02421937  0.00826392 -0.00813786]]
# (Q_a loss:  1.5664
# (Q_b loss:  1.9888
# (Q_a values:  min=9.7168 max=10.4065
# (Targets Q:  min=9.4128 max=14.5414
# (alpha:  0.9194
# log_pi: -2.8136
# target_entropy: -0.8000
# policy loss: -12.1716
# sum: -3.4677
# mean actions: 0.0030
# before gradnorm
# mean_layer grad norm:  4.062664
# dist_layer grad norm:  3.956246
# input_layer grad norm: 0.705841
# after gradnorm
# mean_layer grad norm:  0.320981
# dist_layer grad norm:  0.312573
# input_layer grad norm: 0.055767
# test_mean: [[-0.01484556  0.02677689  0.00694884 -0.00786249]]
# (Q_a loss:  1.3521
# (Q_b loss:  1.7669
# (Q_a values:  min=9.9306 max=10.3991
# (Targets Q:  min=9.6687 max=14.7915
# (alpha:  0.9194
# log_pi: -2.7058
# target_entropy: -0.8000
# policy loss: -12.1565
# sum: -3.5141
# mean actions: 0.0036
# before gradnorm
# mean_layer grad norm:  1.814239
# dist_layer grad norm:  2.338230
# input_layer grad norm: 0.587975
# after gradnorm
# mean_layer grad norm:  0.248121
# dist_layer grad norm:  0.319784
# input_layer grad norm: 0.080413
# test_mean: [[-0.01444634  0.02529974  0.00784887 -0.00905399]]
# (Q_a loss:  1.4081
# (Q_b loss:  1.8262
# (Q_a values:  min=9.9203 max=10.3973
# (Targets Q:  min=9.1862 max=14.8934
# (alpha:  0.9194
# log_pi: -2.7769
# target_entropy: -0.8000
# policy loss: -12.2135
# sum: -3.5392
# mean actions: 0.0000
# before gradnorm
# mean_layer grad norm:  2.749860
# dist_layer grad norm:  2.791690
# input_layer grad norm: 0.653841
# after gradnorm
# mean_layer grad norm:  0.288700
# dist_layer grad norm:  0.293091
# input_layer grad norm: 0.068645
# test_mean: [[-0.01363897  0.026529    0.00601693 -0.00976447]]
# Saved checkpoint to checkpoints/
#   2%|█▍                                                                          | 188/10000 [05:11<4:41:28,  1.72s/it]
# Saved checkpoint to checkpoints/
#   2%|█▍                                                                          | 194/10000 [05:24<6:02:05,  2.22s/it]
# Saved checkpoint to checkpoints/
#   2%|█▌                                                                          | 200/10000 [05:38<5:57:26,  2.19s/it]
# Saved checkpoint to checkpoints/
#   2%|█▌                                                                          | 201/10000 [05:41<6:27:55,  2.38s/it]
# ep 200 | avg reward (last 100): 24.88
#   2%|█▌                                                                          | 206/10000 [05:51<5:57:35,  2.19s/it]
# Saved checkpoint to checkpoints/
#   2%|█▌                                                                          | 211/10000 [06:06<6:23:42,  2.35s/it]
# (Q_a loss:  1.3565
# (Q_b loss:  1.7660
# (Q_a values:  min=10.6970 max=11.3860
# (Targets Q:  min=10.5158 max=15.6436
# (alpha:  0.9039
# log_pi: -2.7642
# target_entropy: -0.8000
# policy loss: -13.0787
# sum: -3.5015
# mean actions: -0.0084
# before gradnorm
# mean_layer grad norm:  3.176884
# dist_layer grad norm:  1.427960
# input_layer grad norm: 0.741862
# after gradnorm
# mean_layer grad norm:  0.367227
# dist_layer grad norm:  0.165063
# input_layer grad norm: 0.085755
# test_mean: [[ 0.00143427  0.01953803 -0.01939188 -0.0107318 ]]
# (Q_a loss:  1.3581
# (Q_b loss:  1.7730
# (Q_a values:  min=10.8157 max=11.3871
# (Targets Q:  min=10.6933 max=15.2216
# (alpha:  0.9039
# log_pi: -2.7362
# target_entropy: -0.8000
# policy loss: -13.1859
# sum: -3.5780
# mean actions: -0.0080
# before gradnorm
# mean_layer grad norm:  1.200761
# dist_layer grad norm:  2.809980
# input_layer grad norm: 0.514437
# after gradnorm
# mean_layer grad norm:  0.158375
# dist_layer grad norm:  0.370623
# input_layer grad norm: 0.067852
# test_mean: [[ 0.00422313  0.02024239 -0.02059881 -0.0102042 ]]
# (Q_a loss:  1.2618
# (Q_b loss:  1.7038
# (Q_a values:  min=10.9339 max=11.3780
# (Targets Q:  min=11.0264 max=14.9776
# (alpha:  0.9039
# log_pi: -2.6580
# target_entropy: -0.8000
# policy loss: -13.0925
# sum: -3.5051
# mean actions: -0.0077
# before gradnorm
# mean_layer grad norm:  1.412166
# dist_layer grad norm:  2.383548
# input_layer grad norm: 0.673256
# after gradnorm
# mean_layer grad norm:  0.204302
# dist_layer grad norm:  0.344834
# input_layer grad norm: 0.097402
# test_mean: [[ 0.00469857  0.02087982 -0.02003134 -0.01136686]]
# (Q_a loss:  1.4447
# (Q_b loss:  1.8599
# (Q_a values:  min=10.7230 max=11.3798
# (Targets Q:  min=10.2241 max=15.2577
# (alpha:  0.9039
# log_pi: -2.7314
# target_entropy: -0.8000
# policy loss: -13.1202
# sum: -3.5172
# mean actions: -0.0091
# before gradnorm
# mean_layer grad norm:  1.983618
# dist_layer grad norm:  3.082584
# input_layer grad norm: 0.816238
# after gradnorm
# mean_layer grad norm:  0.191758
# dist_layer grad norm:  0.297996
# input_layer grad norm: 0.078907
# test_mean: [[ 0.00348642  0.02109324 -0.02073439 -0.0108852 ]]
# Saved checkpoint to checkpoints/
#   2%|█▋                                                                          | 218/10000 [06:21<5:52:12,  2.16s/it]
# Saved checkpoint to checkpoints/
#   2%|█▋                                                                          | 225/10000 [06:37<6:08:50,  2.26s/it]
# Saved checkpoint to checkpoints/
#   2%|█▊                                                                          | 232/10000 [06:52<5:36:59,  2.07s/it]
# Saved checkpoint to checkpoints/
#   2%|█▊                                                                          | 238/10000 [07:06<6:09:15,  2.27s/it]
# Saved checkpoint to checkpoints/
#   2%|█▊                                                                          | 245/10000 [07:22<6:28:30,  2.39s/it]
# (Q_a loss:  1.2228
# (Q_b loss:  1.6459
# (Q_a values:  min=11.8733 max=12.3706
# (Targets Q:  min=12.3107 max=16.0711
# (alpha:  0.8886
# log_pi: -2.6596
# target_entropy: -0.8000
# policy loss: -14.0694
# sum: -3.5224
# mean actions: 0.0107
# before gradnorm
# mean_layer grad norm:  3.097468
# dist_layer grad norm:  1.862158
# input_layer grad norm: 0.591362
# after gradnorm
# mean_layer grad norm:  0.356734
# dist_layer grad norm:  0.214464
# input_layer grad norm: 0.068107
# test_mean: [[ 0.00895236  0.01350848  0.02133458 -0.00078767]]
# (Q_a loss:  1.1415
# (Q_b loss:  1.5684
# (Q_a values:  min=11.9307 max=12.3652
# (Targets Q:  min=11.3062 max=16.6115
# (alpha:  0.8886
# log_pi: -2.6844
# target_entropy: -0.8000
# policy loss: -13.9919
# sum: -3.4377
# mean actions: 0.0084
# before gradnorm
# mean_layer grad norm:  2.144531
# dist_layer grad norm:  2.480476
# input_layer grad norm: 0.596688
# after gradnorm
# mean_layer grad norm:  0.267044
# dist_layer grad norm:  0.308877
# input_layer grad norm: 0.074301
# test_mean: [[ 0.00679161  0.01145916  0.02093213 -0.00103451]]
# (Q_a loss:  1.1077
# (Q_b loss:  1.5357
# (Q_a values:  min=11.9075 max=12.3623
# (Targets Q:  min=11.5652 max=15.8073
# (alpha:  0.8886
# log_pi: -2.7737
# target_entropy: -0.8000
# policy loss: -14.0618
# sum: -3.5163
# mean actions: 0.0099
# before gradnorm
# mean_layer grad norm:  1.569016
# dist_layer grad norm:  1.630029
# input_layer grad norm: 0.528897
# after gradnorm
# mean_layer grad norm:  0.268826
# dist_layer grad norm:  0.279280
# input_layer grad norm: 0.090618
# test_mean: [[0.0070633  0.01399462 0.01954327 0.00104236]]
# (Q_a loss:  1.0672
# (Q_b loss:  1.4606
# (Q_a values:  min=11.8358 max=12.3742
# (Targets Q:  min=11.4642 max=15.3728
# (alpha:  0.8886
# log_pi: -2.7141
# target_entropy: -0.8000
# policy loss: -14.0446
# sum: -3.4901
# mean actions: 0.0088
# before gradnorm
# mean_layer grad norm:  2.164379
# dist_layer grad norm:  1.068280
# input_layer grad norm: 0.541482
# after gradnorm
# mean_layer grad norm:  0.350557
# dist_layer grad norm:  0.173026
# input_layer grad norm: 0.087702
# test_mean: [[0.00671227 0.01604061 0.0183341  0.00139546]]
# Saved checkpoint to checkpoints/
# (Q_a loss:  1.1933
# (Q_b loss:  1.6212
# (Q_a values:  min=11.7243 max=12.3661
# (Targets Q:  min=11.8833 max=16.4223
# (alpha:  0.8886
# log_pi: -2.6793
# target_entropy: -0.8000
# policy loss: -14.0355
# sum: -3.4836
# mean actions: 0.0106
# before gradnorm
# mean_layer grad norm:  3.140457
# dist_layer grad norm:  1.530086
# input_layer grad norm: 0.543767
# after gradnorm
# mean_layer grad norm:  0.371547
# dist_layer grad norm:  0.181024
# input_layer grad norm: 0.064333
# test_mean: [[0.00824965 0.01770455 0.01590006 0.00027884]]
# (Q_a loss:  1.2716
# (Q_b loss:  1.7312
# (Q_a values:  min=11.7582 max=12.3741
# (Targets Q:  min=11.8609 max=15.7580
# (alpha:  0.8886
# log_pi: -2.6578
# target_entropy: -0.8000
# policy loss: -14.1083
# sum: -3.5353
# mean actions: 0.0123
# before gradnorm
# mean_layer grad norm:  1.609127
# dist_layer grad norm:  2.878928
# input_layer grad norm: 0.668893
# after gradnorm
# mean_layer grad norm:  0.202284
# dist_layer grad norm:  0.361911
# input_layer grad norm: 0.084087
# test_mean: [[ 0.00771711  0.01592325  0.01675598 -0.00130324]]
# (Q_a loss:  1.0372
# (Q_b loss:  1.4737
# (Q_a values:  min=11.8470 max=12.3754
# (Targets Q:  min=11.6565 max=16.4065
# (alpha:  0.8886
# log_pi: -2.7237
# target_entropy: -0.8000
# policy loss: -14.0468
# sum: -3.5100
# mean actions: 0.0050
# before gradnorm
# mean_layer grad norm:  5.461735
# dist_layer grad norm:  2.110523
# input_layer grad norm: 0.767136
# after gradnorm
# mean_layer grad norm:  0.408917
# dist_layer grad norm:  0.158014
# input_layer grad norm: 0.057435
# test_mean: [[ 0.00770808  0.01455306  0.01673994 -0.0017895 ]]
# (Q_a loss:  1.2249
# (Q_b loss:  1.6923
# (Q_a values:  min=11.9154 max=12.3714
# (Targets Q:  min=12.0884 max=16.6236
# (alpha:  0.8886
# log_pi: -2.8025
# target_entropy: -0.8000
# policy loss: -14.0749
# sum: -3.5567
# mean actions: 0.0094
# before gradnorm
# mean_layer grad norm:  2.066648
# dist_layer grad norm:  2.409012
# input_layer grad norm: 0.594545
# after gradnorm
# mean_layer grad norm:  0.267907
# dist_layer grad norm:  0.312288
# input_layer grad norm: 0.077073
# test_mean: [[ 0.00907736  0.01624158  0.01463936 -0.00145278]]
# Saved checkpoint to checkpoints/
#   3%|█▉                                                                          | 252/10000 [07:36<5:23:48,  1.99s/it]
# Saved checkpoint to checkpoints/
#   3%|█▉                                                                          | 259/10000 [07:51<6:52:25,  2.54s/it]
# Saved checkpoint to checkpoints/
#   3%|██                                                                          | 264/10000 [08:05<6:33:15,  2.42s/it]
# Saved checkpoint to checkpoints/
#   3%|██                                                                          | 270/10000 [08:21<6:20:52,  2.35s/it]
# Saved checkpoint to checkpoints/
#   3%|██                                                                          | 276/10000 [08:35<6:15:50,  2.32s/it]
# (Q_a loss:  1.1505
# (Q_b loss:  1.5596
# (Q_a values:  min=12.7604 max=13.3695
# (Targets Q:  min=12.2034 max=16.9322
# (alpha:  0.8736
# log_pi: -2.7174
# target_entropy: -0.8000
# policy loss: -15.0138
# sum: -3.5578
# mean actions: -0.0064
# before gradnorm
# mean_layer grad norm:  3.109526
# dist_layer grad norm:  2.967513
# input_layer grad norm: 0.569028
# after gradnorm
# mean_layer grad norm:  0.312938
# dist_layer grad norm:  0.298646
# input_layer grad norm: 0.057266
# test_mean: [[-0.01785781  0.02871911 -0.00085264 -0.01216286]]
# (Q_a loss:  0.9769
# (Q_b loss:  1.4246
# (Q_a values:  min=12.6405 max=13.3702
# (Targets Q:  min=11.8796 max=17.2887
# (alpha:  0.8736
# log_pi: -2.7031
# target_entropy: -0.8000
# policy loss: -15.0352
# sum: -3.5310
# mean actions: -0.0073
# before gradnorm
# mean_layer grad norm:  1.578838
# dist_layer grad norm:  3.289033
# input_layer grad norm: 0.610850
# after gradnorm
# mean_layer grad norm:  0.185517
# dist_layer grad norm:  0.386470
# input_layer grad norm: 0.071776
# test_mean: [[-0.01714071  0.02783906 -0.00103921 -0.01150134]]
# (Q_a loss:  1.0152
# (Q_b loss:  1.4454
# (Q_a values:  min=12.8881 max=13.3671
# (Targets Q:  min=11.9557 max=17.7020
# (alpha:  0.8736
# log_pi: -2.6567
# target_entropy: -0.8000
# policy loss: -15.0190
# sum: -3.5348
# mean actions: -0.0037
# before gradnorm
# mean_layer grad norm:  2.614768
# dist_layer grad norm:  1.388197
# input_layer grad norm: 0.634627
# after gradnorm
# mean_layer grad norm:  0.348338
# dist_layer grad norm:  0.184935
# input_layer grad norm: 0.084545
# test_mean: [[-0.0176934   0.02671168 -0.00062109 -0.012499  ]]
# (Q_a loss:  1.0700
# (Q_b loss:  1.4937
# (Q_a values:  min=12.8528 max=13.3699
# (Targets Q:  min=12.5379 max=16.9205
# (alpha:  0.8736
# log_pi: -2.6816
# target_entropy: -0.8000
# policy loss: -15.0030
# sum: -3.4989
# mean actions: -0.0088
# before gradnorm
# mean_layer grad norm:  0.815902
# dist_layer grad norm:  3.006989
# input_layer grad norm: 0.515719
# after gradnorm
# mean_layer grad norm:  0.103692
# dist_layer grad norm:  0.382154
# input_layer grad norm: 0.065542
# test_mean: [[-0.01836573  0.02565407  0.00045501 -0.01097105]]
# Saved checkpoint to checkpoints/
#   3%|██▏                                                                         | 281/10000 [08:52<8:51:13,  3.28s/it]
# Saved checkpoint to checkpoints/
#   3%|██▏                                                                         | 288/10000 [09:08<6:56:54,  2.58s/it]
# Saved checkpoint to checkpoints/
#   3%|██▏                                                                         | 294/10000 [09:23<7:16:23,  2.70s/it]
# Saved checkpoint to checkpoints/
#   3%|██▎                                                                         | 301/10000 [09:39<6:35:13,  2.44s/it]
# ep 300 | avg reward (last 100): 26.47
# Saved checkpoint to checkpoints/
#   3%|██▎                                                                         | 308/10000 [09:54<5:33:14,  2.06s/it]
# (Q_a loss:  0.7616
# (Q_b loss:  1.1500
# (Q_a values:  min=13.6227 max=14.3882
# (Targets Q:  min=12.7611 max=17.5111
# (alpha:  0.8589
# log_pi: -2.7753
# target_entropy: -0.8000
# policy loss: -15.9624
# sum: -3.5232
# mean actions: 0.0001
# before gradnorm
# mean_layer grad norm:  4.180752
# dist_layer grad norm:  2.914167
# input_layer grad norm: 0.624283
# after gradnorm
# mean_layer grad norm:  0.360779
# dist_layer grad norm:  0.251478
# input_layer grad norm: 0.053873
# test_mean: [[ 0.00174632  0.03309561 -0.00557112 -0.00320955]]
# (Q_a loss:  1.2066
# (Q_b loss:  1.6035
# (Q_a values:  min=13.7902 max=14.3904
# (Targets Q:  min=12.6505 max=17.9315
# (alpha:  0.8589
# log_pi: -2.7063
# target_entropy: -0.8000
# policy loss: -15.9154
# sum: -3.4412
# mean actions: -0.0005
# before gradnorm
# mean_layer grad norm:  2.201958
# dist_layer grad norm:  2.388061
# input_layer grad norm: 0.436146
# after gradnorm
# mean_layer grad norm:  0.275907
# dist_layer grad norm:  0.299226
# input_layer grad norm: 0.054649
# test_mean: [[ 0.0010914   0.03410421 -0.00513717 -0.00358426]]
# (Q_a loss:  1.0004
# (Q_b loss:  1.3626
# (Q_a values:  min=13.5969 max=14.3815
# (Targets Q:  min=13.3948 max=18.0736
# (alpha:  0.8589
# log_pi: -2.6937
# target_entropy: -0.8000
# policy loss: -16.0077
# sum: -3.5720
# mean actions: 0.0007
# before gradnorm
# mean_layer grad norm:  1.844466
# dist_layer grad norm:  1.022645
# input_layer grad norm: 0.599810
# after gradnorm
# mean_layer grad norm:  0.322481
# dist_layer grad norm:  0.178796
# input_layer grad norm: 0.104869
# test_mean: [[ 0.0026227   0.03351355 -0.00450231 -0.00359061]]
# (Q_a loss:  0.9725
# (Q_b loss:  1.3508
# (Q_a values:  min=13.6104 max=14.3834
# (Targets Q:  min=13.2704 max=18.0590
# (alpha:  0.8588
# log_pi: -2.7588
# target_entropy: -0.8000
# policy loss: -15.9826
# sum: -3.5052
# mean actions: -0.0008
# before gradnorm
# mean_layer grad norm:  2.627014
# dist_layer grad norm:  2.527275
# input_layer grad norm: 0.579289
# after gradnorm
# mean_layer grad norm:  0.304978
# dist_layer grad norm:  0.293399
# input_layer grad norm: 0.067251
# test_mean: [[ 0.00207449  0.03528479 -0.00722209 -0.00457461]]
# Saved checkpoint to checkpoints/
#   3%|██▍                                                                         | 316/10000 [10:11<5:58:23,  2.22s/it]
# Saved checkpoint to checkpoints/
#   3%|██▍                                                                         | 324/10000 [10:27<5:10:30,  1.93s/it]
# Saved checkpoint to checkpoints/
#   3%|██▌                                                                         | 331/10000 [10:45<6:51:28,  2.55s/it]
# Saved checkpoint to checkpoints/
#   3%|██▌                                                                         | 335/10000 [10:56<7:24:18,  2.76s/it]
# Saved checkpoint to checkpoints/
#   3%|██▌                                                                         | 342/10000 [11:13<6:10:57,  2.30s/it]
# (Q_a loss:  0.7846
# (Q_b loss:  1.2050
# (Q_a values:  min=14.7214 max=15.4241
# (Targets Q:  min=13.7627 max=18.1901
# (alpha:  0.8443
# log_pi: -2.7508
# target_entropy: -0.8000
# policy loss: -16.9987
# sum: -3.5499
# mean actions: 0.0091
# before gradnorm
# mean_layer grad norm:  3.946810
# dist_layer grad norm:  2.390493
# input_layer grad norm: 0.644854
# after gradnorm
# mean_layer grad norm:  0.370070
# dist_layer grad norm:  0.224143
# input_layer grad norm: 0.060464
# test_mean: [[ 0.02171697  0.02738037  0.01696861 -0.00192703]]
# (Q_a loss:  0.9195
# (Q_b loss:  1.3707
# (Q_a values:  min=14.6464 max=15.4283
# (Targets Q:  min=14.6288 max=18.6661
# (alpha:  0.8443
# log_pi: -2.7549
# target_entropy: -0.8000
# policy loss: -16.9483
# sum: -3.4987
# mean actions: 0.0078
# before gradnorm
# mean_layer grad norm:  2.351435
# dist_layer grad norm:  2.542540
# input_layer grad norm: 0.611131
# after gradnorm
# mean_layer grad norm:  0.266840
# dist_layer grad norm:  0.288527
# input_layer grad norm: 0.069351
# test_mean: [[ 0.02111623  0.02480049  0.01831488 -0.004112  ]]
# (Q_a loss:  0.7466
# (Q_b loss:  1.1524
# (Q_a values:  min=14.7277 max=15.4282
# (Targets Q:  min=14.3599 max=18.4448
# (alpha:  0.8443
# log_pi: -2.7260
# target_entropy: -0.8000
# policy loss: -16.9703
# sum: -3.5023
# mean actions: 0.0080
# before gradnorm
# mean_layer grad norm:  2.481410
# dist_layer grad norm:  2.098107
# input_layer grad norm: 0.550867
# after gradnorm
# mean_layer grad norm:  0.315061
# dist_layer grad norm:  0.266394
# input_layer grad norm: 0.069943
# test_mean: [[ 0.0212865   0.02500635  0.01829974 -0.00401838]]
# (Q_a loss:  0.8371
# (Q_b loss:  1.2447
# (Q_a values:  min=14.6518 max=15.4260
# (Targets Q:  min=14.0817 max=18.1837
# (alpha:  0.8443
# log_pi: -2.6969
# target_entropy: -0.8000
# policy loss: -16.9895
# sum: -3.5250
# mean actions: 0.0080
# before gradnorm
# mean_layer grad norm:  1.658924
# dist_layer grad norm:  2.308377
# input_layer grad norm: 0.453983
# after gradnorm
# mean_layer grad norm:  0.246716
# dist_layer grad norm:  0.343304
# input_layer grad norm: 0.067517
# test_mean: [[ 0.02170718  0.02652576  0.01707885 -0.00347441]]
# Saved checkpoint to checkpoints/
#   3%|██▋                                                                         | 347/10000 [11:26<7:32:36,  2.81s/it]
# Saved checkpoint to checkpoints/
#   4%|██▋                                                                         | 355/10000 [11:45<6:14:04,  2.33s/it]
# Saved checkpoint to checkpoints/
# Saved checkpoint to checkpoints/
#   4%|██▋                                                                         | 360/10000 [11:58<7:20:42,  2.74s/it]
# Saved checkpoint to checkpoints/
#   4%|██▊                                                                         | 365/10000 [12:15<9:40:04,  3.61s/it]
# Saved checkpoint to checkpoints/
#   4%|██▊                                                                         | 373/10000 [12:30<4:47:16,  1.79s/it]
# (Q_a loss:  0.6892
# (Q_b loss:  1.1199
# (Q_a values:  min=15.7710 max=16.4781
# (Targets Q:  min=15.7415 max=19.1403
# (alpha:  0.8301
# log_pi: -2.7172
# target_entropy: -0.8000
# policy loss: -17.9886
# sum: -3.5498
# mean actions: -0.0098
# before gradnorm
# mean_layer grad norm:  3.431767
# dist_layer grad norm:  2.924249
# input_layer grad norm: 0.644598
# after gradnorm
# mean_layer grad norm:  0.319070
# dist_layer grad norm:  0.271883
# input_layer grad norm: 0.059932
# test_mean: [[ 0.00133524  0.01574086 -0.00237529 -0.00982465]]
# (Q_a loss:  0.9325
# (Q_b loss:  1.3598
# (Q_a values:  min=15.6643 max=16.4768
# (Targets Q:  min=14.2195 max=19.2271
# (alpha:  0.8301
# log_pi: -2.6946
# target_entropy: -0.8000
# policy loss: -17.9661
# sum: -3.5290
# mean actions: -0.0096
# before gradnorm
# mean_layer grad norm:  2.112087
# dist_layer grad norm:  3.291408
# input_layer grad norm: 0.578374
# after gradnorm
# mean_layer grad norm:  0.231326
# dist_layer grad norm:  0.360491
# input_layer grad norm: 0.063346
# test_mean: [[ 0.0028063   0.01487191 -0.00179805 -0.01068188]]
# (Q_a loss:  0.8400
# (Q_b loss:  1.2359
# (Q_a values:  min=15.5580 max=16.4763
# (Targets Q:  min=14.7976 max=19.7300
# (alpha:  0.8301
# log_pi: -2.7492
# target_entropy: -0.8000
# policy loss: -18.0228
# sum: -3.5578
# mean actions: -0.0095
# before gradnorm
# mean_layer grad norm:  3.586875
# dist_layer grad norm:  2.779049
# input_layer grad norm: 0.592630
# after gradnorm
# mean_layer grad norm:  0.349496
# dist_layer grad norm:  0.270784
# input_layer grad norm: 0.057744
# test_mean: [[ 0.00270794  0.01518267 -0.00175821 -0.00960246]]
# (Q_a loss:  0.8111
# (Q_b loss:  1.2466
# (Q_a values:  min=15.7042 max=16.4763
# (Targets Q:  min=14.5301 max=19.6017
# (alpha:  0.8301
# log_pi: -2.7511
# target_entropy: -0.8000
# policy loss: -17.9027
# sum: -3.4916
# mean actions: -0.0069
# before gradnorm
# mean_layer grad norm:  2.736932
# dist_layer grad norm:  2.571833
# input_layer grad norm: 0.630956
# after gradnorm
# mean_layer grad norm:  0.310017
# dist_layer grad norm:  0.291316
# input_layer grad norm: 0.071469
# test_mean: [[ 0.0023391   0.01630508 -0.00166089 -0.00714578]]
# Saved checkpoint to checkpoints/
#   4%|██▉                                                                         | 379/10000 [12:46<7:17:54,  2.73s/it]
# Saved checkpoint to checkpoints/
#   4%|██▉                                                                         | 384/10000 [13:01<7:01:30,  2.63s/it]
# Saved checkpoint to checkpoints/
#   4%|██▉                                                                         | 390/10000 [13:17<7:05:38,  2.66s/it]
# Saved checkpoint to checkpoints/
# Saved checkpoint to checkpoints/
#   4%|███                                                                         | 396/10000 [13:31<6:08:45,  2.30s/it]
# Saved checkpoint to checkpoints/
#   4%|███                                                                         | 401/10000 [13:40<5:15:29,  1.97s/it]
# ep 400 | avg reward (last 100): 24.70
#   4%|███                                                                         | 403/10000 [13:46<6:01:41,  2.26s/it]
# (Q_a loss:  0.6164
# (Q_b loss:  0.9475
# (Q_a values:  min=16.9404 max=17.5453
# (Targets Q:  min=15.8387 max=20.0610
# (alpha:  0.8161
# log_pi: -2.7255
# target_entropy: -0.8000
# policy loss: -18.9358
# sum: -3.4889
# mean actions: 0.0006
# before gradnorm
# mean_layer grad norm:  1.628290
# dist_layer grad norm:  1.899486
# input_layer grad norm: 0.577625
# after gradnorm
# mean_layer grad norm:  0.255337
# dist_layer grad norm:  0.297864
# input_layer grad norm: 0.090579
# test_mean: [[ 0.00223725  0.01807431  0.00555038 -0.00212642]]
# (Q_a loss:  0.7603
# (Q_b loss:  1.1722
# (Q_a values:  min=16.4805 max=17.5456
# (Targets Q:  min=16.4149 max=20.4487
# (alpha:  0.8161
# log_pi: -2.7081
# target_entropy: -0.8000
# policy loss: -18.9734
# sum: -3.5216
# mean actions: -0.0029
# before gradnorm
# mean_layer grad norm:  2.907870
# dist_layer grad norm:  1.315027
# input_layer grad norm: 0.582564
# after gradnorm
# mean_layer grad norm:  0.377752
# dist_layer grad norm:  0.170831
# input_layer grad norm: 0.075679
# test_mean: [[ 0.00354001  0.01901455  0.0047803  -0.00393898]]
# (Q_a loss:  0.5888
# (Q_b loss:  0.9478
# (Q_a values:  min=16.6669 max=17.5456
# (Targets Q:  min=15.1746 max=19.9589
# (alpha:  0.8161
# log_pi: -2.7034
# target_entropy: -0.8000
# policy loss: -18.9388
# sum: -3.5540
# mean actions: -0.0029
# before gradnorm
# mean_layer grad norm:  4.503289
# dist_layer grad norm:  1.639854
# input_layer grad norm: 0.671117
# after gradnorm
# mean_layer grad norm:  0.414170
# dist_layer grad norm:  0.150818
# input_layer grad norm: 0.061723
# test_mean: [[ 0.00471264  0.019474    0.00471819 -0.00451133]]
# (Q_a loss:  0.7309
# (Q_b loss:  1.1731
# (Q_a values:  min=16.8057 max=17.5405
# (Targets Q:  min=15.9384 max=20.4476
# (alpha:  0.8161
# log_pi: -2.7232
# target_entropy: -0.8000
# policy loss: -18.9471
# sum: -3.5196
# mean actions: -0.0031
# before gradnorm
# mean_layer grad norm:  2.900333
# dist_layer grad norm:  1.549807
# input_layer grad norm: 0.607976
# after gradnorm
# mean_layer grad norm:  0.356341
# dist_layer grad norm:  0.190412
# input_layer grad norm: 0.074697
# test_mean: [[ 0.00658204  0.01726052  0.00466559 -0.00812218]]
# Saved checkpoint to checkpoints/
#   4%|███                                                                         | 410/10000 [14:04<6:28:07,  2.43s/it]
# Saved checkpoint to checkpoints/
#   4%|███▏                                                                        | 416/10000 [14:20<8:24:46,  3.16s/it]
# Saved checkpoint to checkpoints/
#   4%|███▏                                                                        | 423/10000 [14:34<5:15:12,  1.97s/it]
# Saved checkpoint to checkpoints/
#   4%|███▎                                                                        | 430/10000 [14:50<5:41:12,  2.14s/it]
# Saved checkpoint to checkpoints/
#   4%|███▎                                                                        | 438/10000 [15:07<5:18:42,  2.00s/it]
# (Q_a loss:  0.6170
# (Q_b loss:  0.9243
# (Q_a values:  min=17.6619 max=18.6375
# (Targets Q:  min=16.5614 max=21.4659
# (alpha:  0.8023
# log_pi: -2.7069
# target_entropy: -0.8000
# policy loss: -20.0104
# sum: -3.5531
# mean actions: -0.0033
# before gradnorm
# mean_layer grad norm:  1.507987
# dist_layer grad norm:  2.666322
# input_layer grad norm: 0.591360
# after gradnorm
# mean_layer grad norm:  0.204524
# dist_layer grad norm:  0.361627
# input_layer grad norm: 0.080205
# test_mean: [[ 0.00845077  0.02543188  0.00283028 -0.01470354]]
# (Q_a loss:  0.5623
# (Q_b loss:  0.9496
# (Q_a values:  min=17.7140 max=18.6397
# (Targets Q:  min=16.8976 max=20.9962
# (alpha:  0.8023
# log_pi: -2.7244
# target_entropy: -0.8000
# policy loss: -20.0680
# sum: -3.5505
# mean actions: -0.0067
# before gradnorm
# mean_layer grad norm:  3.387348
# dist_layer grad norm:  0.863047
# input_layer grad norm: 0.436033
# after gradnorm
# mean_layer grad norm:  0.423555
# dist_layer grad norm:  0.107916
# input_layer grad norm: 0.054522
# test_mean: [[ 0.00999588  0.02412035  0.00391232 -0.01565354]]
# (Q_a loss:  0.5919
# (Q_b loss:  0.9775
# (Q_a values:  min=17.9723 max=18.6357
# (Targets Q:  min=16.9355 max=20.8894
# (alpha:  0.8023
# log_pi: -2.7365
# target_entropy: -0.8000
# policy loss: -20.0081
# sum: -3.5176
# mean actions: -0.0035
# before gradnorm
# mean_layer grad norm:  2.571513
# dist_layer grad norm:  2.943220
# input_layer grad norm: 0.568877
# after gradnorm
# mean_layer grad norm:  0.270948
# dist_layer grad norm:  0.310113
# input_layer grad norm: 0.059940
# test_mean: [[ 0.01069428  0.02447623  0.0014449  -0.01511672]]
# (Q_a loss:  0.6344
# (Q_b loss:  1.0028
# (Q_a values:  min=17.8513 max=18.6388
# (Targets Q:  min=16.8928 max=21.4872
# (alpha:  0.8023
# log_pi: -2.7241
# target_entropy: -0.8000
# policy loss: -20.0456
# sum: -3.6006
# mean actions: -0.0021
# before gradnorm
# mean_layer grad norm:  2.578229
# dist_layer grad norm:  1.670378
# input_layer grad norm: 0.569867
# after gradnorm
# mean_layer grad norm:  0.344243
# dist_layer grad norm:  0.223028
# input_layer grad norm: 0.076088
# test_mean: [[ 0.01078275  0.02437335  0.00428215 -0.01490024]]
# Saved checkpoint to checkpoints/
#   4%|███▎                                                                        | 444/10000 [15:23<5:44:58,  2.17s/it]
# Saved checkpoint to checkpoints/
#   4%|███▍                                                                        | 450/10000 [15:39<6:51:35,  2.59s/it]
# Saved checkpoint to checkpoints/
#   5%|███▍                                                                        | 458/10000 [15:55<5:34:58,  2.11s/it]
# Saved checkpoint to checkpoints/
#   5%|███▌                                                                        | 464/10000 [16:11<5:38:16,  2.13s/it]
# Saved checkpoint to checkpoints/
#   5%|███▌                                                                        | 469/10000 [16:24<7:11:38,  2.72s/it]
# (Q_a loss:  0.4381
# (Q_b loss:  0.8039
# (Q_a values:  min=18.3423 max=19.7427
# (Targets Q:  min=17.1007 max=22.7114
# (alpha:  0.7888
# log_pi: -2.7358
# target_entropy: -0.8000
# policy loss: -21.0330
# sum: -3.4858
# mean actions: -0.0093
# before gradnorm
# mean_layer grad norm:  2.642463
# dist_layer grad norm:  1.896898
# input_layer grad norm: 0.755167
# after gradnorm
# mean_layer grad norm:  0.335425
# dist_layer grad norm:  0.240786
# input_layer grad norm: 0.095858
# test_mean: [[ 0.00576507  0.01689432 -0.00596901 -0.01250954]]
# (Q_a loss:  0.4136
# (Q_b loss:  0.7313
# (Q_a values:  min=18.3898 max=19.7411
# (Targets Q:  min=17.8566 max=21.8814
# (alpha:  0.7888
# log_pi: -2.7011
# target_entropy: -0.8000
# policy loss: -21.0416
# sum: -3.5312
# mean actions: -0.0073
# before gradnorm
# mean_layer grad norm:  0.763591
# dist_layer grad norm:  2.033905
# input_layer grad norm: 0.494000
# after gradnorm
# mean_layer grad norm:  0.137810
# dist_layer grad norm:  0.367072
# input_layer grad norm: 0.089155
# test_mean: [[ 0.00673883  0.01705297 -0.00678269 -0.014918  ]]
# (Q_a loss:  0.5902
# (Q_b loss:  0.9782
# (Q_a values:  min=18.6592 max=19.7425
# (Targets Q:  min=17.2665 max=22.5412
# (alpha:  0.7887
# log_pi: -2.7543
# target_entropy: -0.8000
# policy loss: -21.0079
# sum: -3.5088
# mean actions: -0.0073
# before gradnorm
# mean_layer grad norm:  1.453086
# dist_layer grad norm:  0.992577
# input_layer grad norm: 0.523949
# after gradnorm
# mean_layer grad norm:  0.290131
# dist_layer grad norm:  0.198183
# input_layer grad norm: 0.104614
# test_mean: [[ 0.00806101  0.01640325 -0.00830182 -0.01278792]]
# (Q_a loss:  0.5413
# (Q_b loss:  0.8962
# (Q_a values:  min=18.4871 max=19.7428
# (Targets Q:  min=17.9184 max=21.9547
# (alpha:  0.7887
# log_pi: -2.7090
# target_entropy: -0.8000
# policy loss: -21.0874
# sum: -3.5868
# mean actions: -0.0095
# before gradnorm
# mean_layer grad norm:  2.005741
# dist_layer grad norm:  1.797956
# input_layer grad norm: 0.711995
# after gradnorm
# mean_layer grad norm:  0.287731
# dist_layer grad norm:  0.257923
# input_layer grad norm: 0.102138
# test_mean: [[ 0.0089324   0.01678204 -0.01019791 -0.01300742]]
# Saved checkpoint to checkpoints/
#   5%|███▌                                                                        | 474/10000 [16:40<7:53:52,  2.98s/it]
# Saved checkpoint to checkpoints/
#   5%|███▋                                                                        | 483/10000 [16:58<4:58:47,  1.88s/it]
# Saved checkpoint to checkpoints/
#   5%|███▋                                                                        | 490/10000 [17:14<5:34:12,  2.11s/it]
# Saved checkpoint to checkpoints/
#   5%|███▊                                                                        | 495/10000 [17:28<9:05:59,  3.45s/it]
# Saved checkpoint to checkpoints/
#   5%|███▊                                                                        | 501/10000 [17:41<6:03:34,  2.30s/it]
# ep 500 | avg reward (last 100): 23.66
#   5%|███▊                                                                        | 502/10000 [17:45<6:50:16,  2.59s/it]
# (Q_a loss:  0.3240
# (Q_b loss:  0.6094
# (Q_a values:  min=18.8856 max=20.8664
# (Targets Q:  min=17.6175 max=24.2983
# (alpha:  0.7754
# log_pi: -2.6963
# target_entropy: -0.8000
# policy loss: -22.0600
# sum: -3.5233
# mean actions: 0.0078
# before gradnorm
# mean_layer grad norm:  3.183186
# dist_layer grad norm:  1.365055
# input_layer grad norm: 0.562569
# after gradnorm
# mean_layer grad norm:  0.391552
# dist_layer grad norm:  0.167910
# input_layer grad norm: 0.069200
# test_mean: [[ 0.0114185   0.03347092  0.00694644 -0.00274524]]
# (Q_a loss:  0.3546
# (Q_b loss:  0.7124
# (Q_a values:  min=18.8606 max=20.8682
# (Targets Q:  min=17.8584 max=22.9967
# (alpha:  0.7754
# log_pi: -2.7264
# target_entropy: -0.8000
# policy loss: -22.0864
# sum: -3.5360
# mean actions: 0.0117
# before gradnorm
# mean_layer grad norm:  1.111411
# dist_layer grad norm:  3.149298
# input_layer grad norm: 0.473578
# after gradnorm
# mean_layer grad norm:  0.141979
# dist_layer grad norm:  0.402313
# input_layer grad norm: 0.060498
# test_mean: [[ 0.011941    0.03341269  0.00644163 -0.00183552]]
# (Q_a loss:  0.4422
# (Q_b loss:  0.7463
# (Q_a values:  min=19.5368 max=20.8570
# (Targets Q:  min=19.2129 max=23.3043
# (alpha:  0.7754
# log_pi: -2.7467
# target_entropy: -0.8000
# policy loss: -22.0400
# sum: -3.4575
# mean actions: 0.0124
# before gradnorm
# mean_layer grad norm:  2.291010
# dist_layer grad norm:  3.157288
# input_layer grad norm: 0.737830
# after gradnorm
# mean_layer grad norm:  0.236083
# dist_layer grad norm:  0.325351
# input_layer grad norm: 0.076032
# test_mean: [[ 0.01433766  0.03325206  0.00657418 -0.00036119]]
# (Q_a loss:  0.3962
# (Q_b loss:  0.6733
# (Q_a values:  min=19.5232 max=20.8669
# (Targets Q:  min=17.7609 max=22.9693
# (alpha:  0.7754
# log_pi: -2.6978
# target_entropy: -0.8000
# policy loss: -22.1416
# sum: -3.5634
# mean actions: 0.0114
# before gradnorm
# mean_layer grad norm:  2.624137
# dist_layer grad norm:  2.336467
# input_layer grad norm: 0.508536
# after gradnorm
# mean_layer grad norm:  0.329714
# dist_layer grad norm:  0.293569
# input_layer grad norm: 0.063896
# test_mean: [[ 0.01154836  0.03377805  0.00852074 -0.00040016]]
# Saved checkpoint to checkpoints/
#   5%|███▊                                                                        | 508/10000 [18:00<6:56:18,  2.63s/it]
# Saved checkpoint to checkpoints/
#   5%|███▉                                                                        | 515/10000 [18:16<5:52:24,  2.23s/it]
# Saved checkpoint to checkpoints/
#   5%|███▉                                                                        | 521/10000 [18:30<5:31:01,  2.10s/it]
# Saved checkpoint to checkpoints/
#   5%|███▉                                                                        | 525/10000 [18:46<9:22:52,  3.56s/it]
# Saved checkpoint to checkpoints/
#   5%|████                                                                        | 530/10000 [19:00<6:52:01,  2.61s/it]
# (Q_a loss:  0.4691
# (Q_b loss:  0.8882
# (Q_a values:  min=17.4686 max=21.9958
# (Targets Q:  min=17.2481 max=24.3872
# (alpha:  0.7624
# log_pi: -2.7792
# target_entropy: -0.8000
# policy loss: -22.9801
# sum: -3.4864
# mean actions: 0.0067
# before gradnorm
# mean_layer grad norm:  2.642593
# dist_layer grad norm:  3.248064
# input_layer grad norm: 0.691672
# after gradnorm
# mean_layer grad norm:  0.257452
# dist_layer grad norm:  0.316439
# input_layer grad norm: 0.067385
# test_mean: [[ 0.00899493  0.0284839  -0.0014158   0.00508417]]
# (Q_a loss:  0.3857
# (Q_b loss:  0.8385
# (Q_a values:  min=18.2936 max=22.0022
# (Targets Q:  min=16.9133 max=24.1879
# (alpha:  0.7624
# log_pi: -2.7163
# target_entropy: -0.8000
# policy loss: -22.9150
# sum: -3.5350
# mean actions: 0.0067
# before gradnorm
# mean_layer grad norm:  1.915547
# dist_layer grad norm:  1.651956
# input_layer grad norm: 0.397231
# after gradnorm
# mean_layer grad norm:  0.310881
# dist_layer grad norm:  0.268102
# input_layer grad norm: 0.064468
# test_mean: [[0.00757124 0.0270155  0.00083024 0.00524462]]
# (Q_a loss:  0.3567
# (Q_b loss:  0.6842
# (Q_a values:  min=18.6337 max=21.9939
# (Targets Q:  min=18.6343 max=24.2675
# (alpha:  0.7624
# log_pi: -2.6920
# target_entropy: -0.8000
# policy loss: -23.0299
# sum: -3.4941
# mean actions: 0.0070
# before gradnorm
# mean_layer grad norm:  1.638053
# dist_layer grad norm:  0.849476
# input_layer grad norm: 0.492742
# after gradnorm
# mean_layer grad norm:  0.339554
# dist_layer grad norm:  0.176089
# input_layer grad norm: 0.102141
# test_mean: [[0.0075695  0.02638977 0.00046928 0.00530006]]
# (Q_a loss:  0.3465
# (Q_b loss:  0.6682
# (Q_a values:  min=19.1525 max=22.0011
# (Targets Q:  min=17.2531 max=24.4553
# (alpha:  0.7624
# log_pi: -2.7779
# target_entropy: -0.8000
# policy loss: -23.0151
# sum: -3.4825
# mean actions: 0.0072
# before gradnorm
# mean_layer grad norm:  1.067134
# dist_layer grad norm:  1.036938
# input_layer grad norm: 0.426266
# after gradnorm
# mean_layer grad norm:  0.249306
# dist_layer grad norm:  0.242252
# input_layer grad norm: 0.099585
# test_mean: [[ 0.00700392  0.02724573 -0.00027658  0.00592249]]
# Saved checkpoint to checkpoints/
#   5%|████                                                                        | 537/10000 [19:17<7:27:47,  2.84s/it]
# Saved checkpoint to checkpoints/
#   5%|████▏                                                                       | 543/10000 [19:34<8:09:27,  3.11s/it]
# Saved checkpoint to checkpoints/
#   5%|████▏                                                                       | 549/10000 [19:49<7:13:40,  2.75s/it]
# Saved checkpoint to checkpoints/
#   6%|████▏                                                                       | 555/10000 [20:04<6:42:16,  2.56s/it]
# Saved checkpoint to checkpoints/
# ...
# test_mean: [[0.5367225  0.70533997 0.64158535 0.69534004]]
# Saved checkpoint to checkpoints/
# Saved checkpoint to checkpoints/
#  26%|██████████████████▍                                                    | 2599/10000 [4:24:42<140:51:06, 68.51s/it]
# Saved checkpoint to checkpoints/
#  26%|██████████████████▍                                                    | 2600/10000 [4:25:22<123:12:36, 59.94s/it]
# Saved checkpoint to checkpoints/
# Saved checkpoint to checkpoints/
# (Q_a loss:  0.1101
# (Q_b loss:  0.1265
# (Q_a values:  min=-5.5263 max=28.3801
# (Targets Q:  min=-5.8170 max=28.6373
# (alpha:  0.0757
# log_pi: -0.7692
# target_entropy: -0.8000
# policy loss: -14.8028
# sum: -1.4658
# mean actions: 0.1615
# before gradnorm
# mean_layer grad norm:  0.383497
# dist_layer grad norm:  0.253787
# input_layer grad norm: 0.115504
# after gradnorm
# mean_layer grad norm:  0.287600
# dist_layer grad norm:  0.190326
# input_layer grad norm: 0.086621
# test_mean: [[0.6122154 0.6650465 0.5997555 0.7828368]]
# (Q_a loss:  0.1331
# (Q_b loss:  0.1125
# (Q_a values:  min=-1.3206 max=28.4825
# (Targets Q:  min=-1.5423 max=28.5006
# (alpha:  0.0757
# log_pi: -0.2444
# target_entropy: -0.8000
# policy loss: -15.0461
# sum: -1.3628
# mean actions: 0.1941
# before gradnorm
# mean_layer grad norm:  0.306002
# dist_layer grad norm:  0.221075
# input_layer grad norm: 0.096517
# after gradnorm
# mean_layer grad norm:  0.280081
# dist_layer grad norm:  0.202348
# input_layer grad norm: 0.088341
# test_mean: [[0.6118711  0.78710246 0.61352575 0.68662673]]
# (Q_a loss:  0.1026
# (Q_b loss:  0.1317
# (Q_a values:  min=-5.0450 max=27.5603
# (Targets Q:  min=-5.2836 max=27.9938
# (alpha:  0.0757
# log_pi: -0.3904
# target_entropy: -0.8000
# policy loss: -14.9611
# sum: -0.8386
# mean actions: 0.1495
# before gradnorm
# mean_layer grad norm:  0.274292
# dist_layer grad norm:  0.324902
# input_layer grad norm: 0.108986
# after gradnorm
# mean_layer grad norm:  0.232854
# dist_layer grad norm:  0.275819
# input_layer grad norm: 0.092521
# test_mean: [[0.599524   0.7557421  0.58631    0.67761195]]
# (Q_a loss:  0.1223
# (Q_b loss:  0.1432
# (Q_a values:  min=-6.1999 max=28.2678
# (Targets Q:  min=-6.0968 max=28.0378
# (alpha:  0.0757
# log_pi: -0.5886
# target_entropy: -0.8000
# policy loss: -14.7904
# sum: -1.0769
# mean actions: 0.1730
# before gradnorm
# mean_layer grad norm:  0.541311
# dist_layer grad norm:  0.150366
# input_layer grad norm: 0.103528
# after gradnorm
# mean_layer grad norm:  0.375579
# dist_layer grad norm:  0.104329
# input_layer grad norm: 0.071831
# test_mean: [[0.56154174 0.71449596 0.63295823 0.72676843]]
# Saved checkpoint to checkpoints/
# Saved checkpoint to checkpoints/
# Saved checkpoint to checkpoints/
# Saved checkpoint to checkpoints/
# Saved checkpoint to checkpoints/
#  26%|██████████████████▏                                                   | 2601/10000 [4:29:03<222:32:58, 108.28s/it]
# ep 2600 | avg reward (last 100): 379.80
# (Q_a loss:  0.1277
# (Q_b loss:  0.1584
# (Q_a values:  min=-2.2432 max=27.2080
# (Targets Q:  min=-1.9791 max=27.9914
# (alpha:  0.0746
# log_pi: -0.7518
# target_entropy: -0.8000
# policy loss: -14.9655
# sum: -1.3770
# mean actions: 0.1565
# before gradnorm
# mean_layer grad norm:  0.395187
# dist_layer grad norm:  0.227651
# input_layer grad norm: 0.124778
# after gradnorm
# mean_layer grad norm:  0.322190
# dist_layer grad norm:  0.185600
# input_layer grad norm: 0.101730
# test_mean: [[0.38407272 0.80310106 0.79585934 0.5482535 ]]
# (Q_a loss:  0.0993
# (Q_b loss:  0.1600
# (Q_a values:  min=-4.1256 max=28.1969
# (Targets Q:  min=-3.6955 max=28.5737
# (alpha:  0.0746
# log_pi: -0.1517
# target_entropy: -0.8000
# policy loss: -14.7735
# sum: -1.4231
# mean actions: 0.1638
# before gradnorm
# mean_layer grad norm:  0.339694
# dist_layer grad norm:  0.440224
# input_layer grad norm: 0.136631
# after gradnorm
# mean_layer grad norm:  0.231444
# dist_layer grad norm:  0.299938
# input_layer grad norm: 0.093091
# test_mean: [[0.42899045 0.771587   0.7684623  0.61091006]]
# (Q_a loss:  0.1085
# (Q_b loss:  0.1023
# (Q_a values:  min=-6.3522 max=27.0479
# (Targets Q:  min=-6.9114 max=25.8476
# (alpha:  0.0746
# log_pi: -0.4348
# target_entropy: -0.8000
# policy loss: -14.9922
# sum: -1.4105
# mean actions: 0.1662
# before gradnorm
# mean_layer grad norm:  0.289964
# dist_layer grad norm:  0.314067
# input_layer grad norm: 0.107965
# after gradnorm
# mean_layer grad norm:  0.254599
# dist_layer grad norm:  0.275762
# input_layer grad norm: 0.094798
# test_mean: [[0.49875712 0.7481224  0.7039886  0.6542996 ]]
# (Q_a loss:  0.1622
# (Q_b loss:  0.1460
# (Q_a values:  min=-6.7772 max=28.6572
# (Targets Q:  min=-5.5847 max=29.1256
# (alpha:  0.0746
# log_pi: -0.4481
# target_entropy: -0.8000
# policy loss: -15.1378
# sum: -1.2574
# mean actions: 0.1607
# before gradnorm
# mean_layer grad norm:  0.487037
# dist_layer grad norm:  0.207875
# input_layer grad norm: 0.120969
# after gradnorm
# mean_layer grad norm:  0.350109
# dist_layer grad norm:  0.149432
# input_layer grad norm: 0.086959
# test_mean: [[0.4375854  0.73803264 0.75057834 0.6475671 ]]
# Saved checkpoint to checkpoints/
# Saved checkpoint to checkpoints/
# Saved checkpoint to checkpoints/
#  26%|██████████████████▏                                                   | 2602/10000 [4:30:35<212:18:26, 103.31s/it]
# Saved checkpoint to checkpoints/
# Saved checkpoint to checkpoints/
#  26%|██████████████████▍                                                    | 2603/10000 [4:31:48<193:25:40, 94.14s/it]
# (Q_a loss:  0.1202
# (Q_b loss:  0.1330
# (Q_a values:  min=-6.8210 max=27.5894
# (Targets Q:  min=-5.6294 max=27.4313
# (alpha:  0.0734
# log_pi: -0.5026
# target_entropy: -0.8000
# policy loss: -14.7781
# sum: -1.4260
# mean actions: 0.1247
# before gradnorm
# mean_layer grad norm:  0.365936
# dist_layer grad norm:  0.197121
# input_layer grad norm: 0.131681
# after gradnorm
# mean_layer grad norm:  0.299557
# dist_layer grad norm:  0.161364
# input_layer grad norm: 0.107795
# test_mean: [[0.45466667 0.5166098  0.70301366 0.74661946]]
# (Q_a loss:  0.0975
# (Q_b loss:  0.0891
# (Q_a values:  min=-4.4452 max=24.7721
# (Targets Q:  min=-5.0222 max=25.2498
# (alpha:  0.0734
# log_pi: -0.6129
# target_entropy: -0.8000
# policy loss: -14.8373
# sum: -1.2014
# mean actions: 0.1228
# before gradnorm
# mean_layer grad norm:  0.500244
# dist_layer grad norm:  0.366925
# input_layer grad norm: 0.103561
# after gradnorm
# mean_layer grad norm:  0.329721
# dist_layer grad norm:  0.241848
# input_layer grad norm: 0.068260
# test_mean: [[0.5151415  0.5005386  0.65322894 0.7815592 ]]
# (Q_a loss:  0.1427
# (Q_b loss:  0.1490
# (Q_a values:  min=-2.9371 max=27.4432
# (Targets Q:  min=-2.9479 max=26.8781
# (alpha:  0.0734
# log_pi: -0.5892
# target_entropy: -0.8000
# policy loss: -14.9308
# sum: -1.0331
# mean actions: 0.1399
# before gradnorm
# mean_layer grad norm:  0.485764
# dist_layer grad norm:  0.399100
# input_layer grad norm: 0.107131
# after gradnorm
# mean_layer grad norm:  0.314637
# dist_layer grad norm:  0.258503
# input_layer grad norm: 0.069390
# test_mean: [[0.50406355 0.5726579  0.6770652  0.7409505 ]]
# (Q_a loss:  0.1199
# (Q_b loss:  0.1401
# (Q_a values:  min=-6.3398 max=26.3677
# (Targets Q:  min=-6.5634 max=26.8908
# (alpha:  0.0734
# log_pi: -0.6445
# target_entropy: -0.8000
# policy loss: -15.0514
# sum: -1.4415
# mean actions: 0.1432
# before gradnorm
# mean_layer grad norm:  0.159470
# dist_layer grad norm:  0.373314
# input_layer grad norm: 0.128297
# after gradnorm
# mean_layer grad norm:  0.135114
# dist_layer grad norm:  0.316298
# input_layer grad norm: 0.108703
# test_mean: [[0.48860866 0.5896603  0.68436325 0.71113133]]
# Saved checkpoint to checkpoints/
# Saved checkpoint to checkpoints/
#  26%|██████████████████▍                                                    | 2604/10000 [4:32:41<168:07:50, 81.84s/it]
# Saved checkpoint to checkpoints/
# Saved checkpoint to checkpoints/
# Saved checkpoint to checkpoints/
#  26%|██████████████████▍                                                    | 2605/10000 [4:34:24<181:02:55, 88.14s/it]
# (Q_a loss:  0.1584
# (Q_b loss:  0.1723
# (Q_a values:  min=-1.9460 max=26.0960
# (Targets Q:  min=-2.2141 max=25.5190
# (alpha:  0.0722
# log_pi: -0.3398
# target_entropy: -0.8000
# policy loss: -14.9067
# sum: -1.8927
# mean actions: 0.1553
# before gradnorm
# mean_layer grad norm:  0.296486
# dist_layer grad norm:  0.458331
# input_layer grad norm: 0.119271
# after gradnorm
# mean_layer grad norm:  0.209950
# dist_layer grad norm:  0.324556
# input_layer grad norm: 0.084459
# test_mean: [[0.40341628 0.6620537  0.8146433  0.72456455]]
# (Q_a loss:  0.1577
# (Q_b loss:  0.1630
# (Q_a values:  min=-3.6027 max=26.2333
# (Targets Q:  min=-3.7802 max=25.9053
# (alpha:  0.0722
# log_pi: -0.6976
# target_entropy: -0.8000
# policy loss: -14.9083
# sum: -1.3847
# mean actions: 0.1570
# before gradnorm
# mean_layer grad norm:  0.394325
# dist_layer grad norm:  0.418137
# input_layer grad norm: 0.117342
# after gradnorm
# mean_layer grad norm:  0.269471
# dist_layer grad norm:  0.285743
# input_layer grad norm: 0.080188
# test_mean: [[0.41204497 0.65640306 0.80030787 0.74529725]]
# (Q_a loss:  0.1626
# (Q_b loss:  0.1218
# (Q_a values:  min=-4.5760 max=26.4981
# (Targets Q:  min=-4.4721 max=26.7187
# (alpha:  0.0722
# log_pi: -0.6843
# target_entropy: -0.8000
# policy loss: -14.9649
# sum: -1.0447
# mean actions: 0.1511
# before gradnorm
# mean_layer grad norm:  0.407910
# dist_layer grad norm:  0.224018
# input_layer grad norm: 0.109104
# after gradnorm
# mean_layer grad norm:  0.317927
# dist_layer grad norm:  0.174601
# input_layer grad norm: 0.085036
# test_mean: [[0.41272292 0.66159606 0.7816668  0.71069396]]
# (Q_a loss:  0.1725
# (Q_b loss:  0.1185
# (Q_a values:  min=-6.2358 max=27.5615
# (Targets Q:  min=-4.5213 max=27.8414
# (alpha:  0.0722
# log_pi: -0.3528
# target_entropy: -0.8000
# policy loss: -14.7259
# sum: -1.0893
# mean actions: 0.1406
# before gradnorm
# mean_layer grad norm:  0.435715
# dist_layer grad norm:  0.416744
# input_layer grad norm: 0.119094
# after gradnorm
# mean_layer grad norm:  0.278615
# dist_layer grad norm:  0.266484
# input_layer grad norm: 0.076153
# test_mean: [[0.42117602 0.6022076  0.7797407  0.76793545]]
# Saved checkpoint to checkpoints/
#  26%|██████████████████▊                                                     | 2605/10000 [4:34:52<13:00:19,  6.33s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 rewards,a,b,c,d,e,f = SAC_PER(env, resume=True)
#
# Cell In[52], line 90, in SAC_PER(env, resume)
#      75 target_q_network_b.eval()
#      83 agent = Agent(env, ReplayMemory, online_policy_network, online_q_network_a, online_q_network_b,\
#      84             online_policy_optimizer,online_qa_network_optimizer, online_qb_network_optimizer, target_q_network_a,\
#      85             target_q_network_b, gamma=gamma__, alpha_pr=alpha_pr__, beta_pr=beta_pr__,\
#      86             tau=tau__, n_ep=n_ep__, max_steps=1000000, memory_size=memory_size__, batch_size=batch_size__,\
#      87             policy_update_step=policy_update_step__, target_update=target_update__, min_sample_size=min_sample_size__,\
#      88             warm_up=5, rank_based_prioritization=True, utd_ratio = utd_ratio__)
# ---> 90 rewards = agent.train()
#      91 return rewards, online_q_network_a, online_q_network_b,\
#      92 online_policy_network, online_qa_network_optimizer,\
#      93 online_qb_network_optimizer, online_policy_optimizer
#
# Cell In[16], line 357, in Agent.train(self)
#     353 experience_samples = self.agent_memory.sample(self.batch_size)
#     354 weighted_importance, indices =\
#     355     self.prioritize_samples(experience_samples, self.alpha_pr, self.beta_pr)
#     356 experiences_rebuilded, timesteps, metrics = \
# --> 357     self.update_model(experience_samples, weighted_importance, indices)
#     358 self.agent_memory.update_td_error(experiences_rebuilded, timesteps)
#     361 if self.current_timestep % self.target_update == 0:
#
# Cell In[16], line 162, in Agent.update_model(self, experience_samples, weighted_importance, timestep_indices)
#     160 qb_loss.backward()
#     161 torch.nn.utils.clip_grad_norm_(self.online_q_network_b.parameters(), max_norm=self.max_norm)  # ← here
# --> 162 self.online_q_network_optimizer_b.step()
#     164 abs_a = (target_qsa.squeeze() - qsa_online_a.squeeze())
#     165 abs_b = (target_qsa.squeeze() - qsa_online_b.squeeze())
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\optim\optimizer.py:526, in Optimizer.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#     521             raise RuntimeError(
#     522                 f"{func} must return None or a tuple of (new_args, new_kwargs), but got {result}."
#     523             )
#     525 # pyrefly: ignore [invalid-param-spec]
# --> 526 out = func(*args, **kwargs)
#     527 self._optimizer_step_code()
#     529 # call optimizer step post hooks
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\optim\optimizer.py:81, in _use_grad_for_differentiable.<locals>._use_grad(*args, **kwargs)
#      79     torch.set_grad_enabled(self.defaults["differentiable"])
#      80     torch._dynamo.graph_break()
# ---> 81     ret = func(*args, **kwargs)
#      82 finally:
#      83     torch._dynamo.graph_break()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\optim\adam.py:248, in Adam.step(self, closure)
#     236     beta1, beta2 = group["betas"]
#     238     has_complex = self._init_group(
#     239         group,
#     240         params_with_grad,
#    (...)    245         state_steps,
#     246     )
# --> 248     adam(
#     249         params_with_grad,
#     250         grads,
#     251         exp_avgs,
#     252         exp_avg_sqs,
#     253         max_exp_avg_sqs,
#     254         state_steps,
#     255         amsgrad=group["amsgrad"],
#     256         has_complex=has_complex,
#     257         beta1=beta1,
#     258         beta2=beta2,
#     259         lr=group["lr"],
#     260         weight_decay=group["weight_decay"],
#     261         eps=group["eps"],
#     262         maximize=group["maximize"],
#     263         foreach=group["foreach"],
#     264         capturable=group["capturable"],
#     265         differentiable=group["differentiable"],
#     266         fused=group["fused"],
#     267         grad_scale=getattr(self, "grad_scale", None),
#     268         found_inf=getattr(self, "found_inf", None),
#     269         decoupled_weight_decay=group["decoupled_weight_decay"],
#     270     )
#     272 return loss
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\optim\optimizer.py:151, in _disable_dynamo_if_unsupported.<locals>.wrapper.<locals>.maybe_fallback(*args, **kwargs)
#     149     return disabled_func(*args, **kwargs)
#     150 else:
# --> 151     return func(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\optim\adam.py:970, in adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, foreach, capturable, differentiable, fused, grad_scale, found_inf, has_complex, decoupled_weight_decay, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize)
#     967 else:
#     968     func = _single_tensor_adam
# --> 970 func(
#     971     params,
#     972     grads,
#     973     exp_avgs,
#     974     exp_avg_sqs,
#     975     max_exp_avg_sqs,
#     976     state_steps,
#     977     amsgrad=amsgrad,
#     978     has_complex=has_complex,
#     979     beta1=beta1,
#     980     beta2=beta2,
#     981     lr=lr,
#     982     weight_decay=weight_decay,
#     983     eps=eps,
#     984     maximize=maximize,
#     985     capturable=capturable,
#     986     differentiable=differentiable,
#     987     grad_scale=grad_scale,
#     988     found_inf=found_inf,
#     989     decoupled_weight_decay=decoupled_weight_decay,
#     990 )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\optim\adam.py:545, in _single_tensor_adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, grad_scale, found_inf, amsgrad, has_complex, beta1, beta2, lr, weight_decay, eps, maximize, capturable, differentiable, decoupled_weight_decay)
#     543         denom = (max_exp_avg_sqs[i].sqrt() / bias_correction2_sqrt).add_(eps)
#     544     else:
# --> 545         denom = (exp_avg_sq.sqrt() / bias_correction2_sqrt).add_(eps)
#     547     param.addcdiv_(exp_avg, denom, value=-step_size)  # type: ignore[arg-type]
#     549 # Lastly, switch back to complex view
#
# KeyboardInterrupt:

# %%
save_checkpoint(a, b, c, rewards)
# Out:
# Saved checkpoint to checkpoints/

# %%
#plot_grad_flow(online_q_network_a.named_parameters())
env.close()

# %%
plot_grad_flow(c.named_parameters())

# %%
def plot_grad_flow(named_parameters):
    ave_grads = []
    layers = []
    for n, p in named_parameters:
        if p.requires_grad and "bias" not in n and "bn" not in n:  # ← skip bn layers
            layers.append(n)
            ave_grads.append(p.grad.abs().mean().detach().cpu().numpy())
    plt.plot(ave_grads, alpha=0.3, color="b")
    plt.hlines(0, 0, len(ave_grads)+1, linewidth=1, color="k")
    plt.xticks(range(0, len(ave_grads), 1), layers, rotation="vertical")
    plt.xlim(xmin=0, xmax=len(ave_grads))
    plt.xlabel("Layers")
    plt.ylabel("average gradient")
    plt.title("Gradient flow")
    plt.grid(True)
plot_grad_flow(c.named_parameters())

# %%
print(a)
# Out:
# FCQV(
#   (input_layer): Linear(in_features=20, out_features=128, bias=True)
#   (input_bn): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (hidden_layers): ModuleList(
#     (0-1): 2 x Linear(in_features=132, out_features=128, bias=True)
#   )
#   (hidden_bn): ModuleList(
#     (0-1): 2 x BatchNorm1d(132, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (output_batch_norm): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (output_layer): Linear(in_features=128, out_features=1, bias=True)
# )

# %%
print(b)
# Out:
# FCQV(
#   (input_layer): Linear(in_features=20, out_features=128, bias=True)
#   (input_bn): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (hidden_layers): ModuleList(
#     (0-1): 2 x Linear(in_features=132, out_features=128, bias=True)
#   )
#   (hidden_bn): ModuleList(
#     (0-1): 2 x BatchNorm1d(132, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (output_batch_norm): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (output_layer): Linear(in_features=128, out_features=1, bias=True)
# )

# %%
acc_
# Out:
# [21.437025278879446,
#  21.480350254219957,
#  21.322382675483823,
#  21.49241150083253,
#  21.38842058472801,
#  21.2759058913216,
#  21.422967745456845,
#  21.23207057081163,
#  21.40658881282434,
#  21.402483746409416,
#  21.47780599608086,
#  21.288555908948183,
#  21.414072196668712,
#  21.44170862296596,
#  21.36946716415696,
#  21.358401192934252,
#  21.311748754233122,
#  21.44514578883536,
#  21.277212105691433,
#  21.511831995332614,
#  21.286870657466352,
#  21.299994016066194,
#  21.30471672490239,
#  21.413186008576304,
#  21.39767190022394,
#  21.250682690180838,
#  21.403829135466367,
#  21.519212752595195,
#  21.149476952268742,
#  21.4772374444874,
#  21.296425852924585,
#  21.45965313888155,
#  21.334488043095917,
#  21.45035059377551,
#  21.382268273853697,
#  21.484152794932015,
#  21.21666512452066,
#  21.44586174469441,
#  21.381436940748245,
#  21.4289539570309,
#  21.437252297764644,
#  21.45585540216416,
#  21.443648722721264,
#  21.359752946766093,
#  21.52105789153211,
#  21.31932983198203,
#  21.472803795710206,
#  21.412639553043846,
#  21.304851546883583,
#  21.408139356935862,
#  21.36038567381911,
#  21.389608842873713,
#  21.283932547084987,
#  21.259823573054746,
#  21.353974507190287,
#  21.44276036322117,
#  21.376406942494214,
#  21.467917711357586,
#  21.358243050053716,
#  21.307292751967907,
#  21.429422799497843,
#  21.40814026692533,
#  21.412637013972926,
#  21.48556795308832,
#  21.43136990396306,
#  21.41768445307389,
#  21.449409891618416,
#  21.409568707924336,
#  21.408081257424783,
#  21.43807411848684,
#  21.410926264496993,
#  21.390260884421878,
#  21.41281648958102,
#  21.322451912332326,
#  21.321274505695328,
#  21.19969072774984,
#  21.174062776379287,
#  21.329536585137248,
#  21.4106509004871,
#  21.431188108457718,
#  21.39938958734274,
#  21.43344619241543,
#  21.324681445024908,
#  21.51936374955403,
#  21.49699347896967,
#  21.389009729842655,
#  21.508736169314943,
#  21.293379339389503,
#  21.26430276921019,
#  21.25995393563062,
#  21.424502106383443,
#  21.49899304326391,
#  21.175282885553315,
#  21.29009426664561,
#  21.3902006582357,
#  21.412879444658756,
#  21.493814983405173,
#  21.27174775954336,
#  21.39266079047229,
#  21.489204504177906,
#  21.408401747699827,
#  21.385184959275648,
#  21.461753058829345,
#  21.290375497192144,
#  21.481562129687518,
#  21.38257275687647,
#  21.176756044384092,
#  21.430840451736003,
#  21.519066565480898,
#  21.447240421315655,
#  21.29025323782116,
#  21.51062986688339,
#  21.43169972812757,
#  21.111568251042627,
#  21.292056654579937,
#  21.41284068953246,
#  21.433448769239476,
#  21.156109726056457,
#  21.42345446240506,
#  21.14073245669715,
#  21.288314825855196,
#  21.408375614555553,
#  21.24169113393873,
#  21.424353313166648,
#  21.499500824138522,
#  21.36665434698807,
#  21.412819645396667,
#  21.296388978138566,
#  21.390213345643133,
#  21.389546437654644,
#  21.408637602464296,
#  21.386005103122443,
#  21.491298991139047,
#  21.409703691489995,
#  21.47906407364644,
#  21.334250044543296,
#  21.435625308426097,
#  21.40103470149188,
#  21.400851835031062,
#  21.394005757407285,
#  21.414238083641976,
#  21.447731545427814,
#  21.44059753944748,
#  21.31663959287107,
#  21.40726562880809,
#  21.340938406065106,
#  21.219253532821313,
#  21.443282075080788,
#  21.43592588653337,
#  21.449768438003957,
#  21.307187298312783,
#  21.33148218365386,
#  21.407137299655005,
#  21.433055400964804,
#  21.29531091451645,
#  21.3502319897525,
#  21.307024849578738,
#  21.49813311523758,
#  21.268001651391387,
#  21.440847327932715,
#  21.418671846258803,
#  21.43194890860468,
#  21.337503989692777,
#  21.33628406189382,
#  21.431820804718882,
#  21.30949900392443,
#  21.484162651002407,
#  21.324797427281737,
#  21.41701601445675,
#  21.405013824405614,
#  21.305984368547797,
#  21.2702175648883,
#  21.45515733701177,
#  21.3842245163396,
#  21.249369020573795,
#  21.335733454674482,
#  21.492371310130693,
#  21.48477791622281,
#  21.32057636603713,
#  21.34439520072192,
#  21.291486504487693,
#  21.325369108701125,
#  21.293915202841163,
#  21.42526255780831,
#  21.41596911045781,
#  21.506148334417958,
#  21.40940502394551,
#  21.521295540998835,
#  21.2530081467703,
#  21.520389172994328,
#  21.43509330227971,
#  21.414916632282257,
#  21.18903440516442,
#  21.39208421384683,
#  21.242364312987775,
#  21.19527235068381,
#  21.423040956113255,
#  21.464367157197557,
#  21.443739612819627,
#  21.302154841832817,
#  21.295593412593007,
#  21.289200438186526,
#  21.342624380486086,
#  21.30013852287084,
#  21.413449977910204,
#  21.38770166784525,
#  21.314296948723495,
#  21.343642173800617,
#  21.359365750220604,
#  21.35663049481809,
#  21.45763337612152,
#  21.515833016630495,
#  21.361929446225986,
#  21.38026256894227,
#  21.368892881262582,
#  21.251958664506674,
#  21.236186248948798,
#  21.218362531624734,
#  21.407982527744025,
#  21.30543429404497,
#  21.430329096037894,
#  21.291494289413095,
#  21.51003855728777,
#  21.291890675667673,
#  21.256217593327165,
#  21.507613534631673,
#  21.423918208573014,
#  21.226772781461477,
#  21.363187929266132,
#  21.23446675762534,
#  21.37039270065725,
#  21.454758539097384,
#  21.280889671761543,
#  21.391559846088057,
#  21.37237756513059,
#  21.335850456962362,
#  21.46127722179517,
#  21.27653327025473,
#  21.50863759368076,
#  21.409494530118536,
#  21.50336534244707,
#  21.398040557745844,
#  21.422722385032102,
#  21.433169185882434,
#  21.42130845808424,
#  21.464043865678832,
#  21.1847732514143,
#  21.32812072976958,
#  21.40920719242422,
#  21.493343878828455,
#  21.35014062630944,
#  21.39219044226047,
#  21.33199716359377,
#  21.487009322852828,
#  21.51471942194621,
#  21.40685049968306,
#  21.28888793103397,
#  21.45088646491058,
#  21.496516130573582,
#  21.484854226117022,
#  21.50749672134407,
#  21.304777255281806,
#  21.402792085020337,
#  21.259095306042582,
#  21.3451811025152,
#  21.298922836780548,
#  21.34092641924508,
#  21.398237988352776,
#  21.328669857233763,
#  21.183847587555647,
#  21.442557436181232,
#  21.37127700331621,
#  21.309453142341226,
#  21.505788256938104,
#  21.509309801185736,
#  21.324960936792195,
#  21.210383015219122,
#  21.52032782023889,
#  21.442377572413534,
#  21.213733660057187,
#  21.448179536731914,
#  21.47534856654238,
#  21.41366387018934,
#  21.408826993429102,
#  21.33795117586851,
#  21.416734292404726,
#  21.25721252709627,
#  21.518391519319266,
#  21.407124409888638,
#  21.372986001195386,
#  21.417458767537028,
#  21.31987579818815,
#  21.35007817740552,
#  21.499001522315666,
#  21.46652262005955,
#  21.443644581828266,
#  21.473671661689878,
#  21.193227497162297,
#  21.249924377538264,
#  21.402119241305627,
#  21.390627180087904,
#  21.367417998611927,
#  21.38783516775584,
#  21.34648406575434,
#  21.28892911877483,
#  21.3161360793747,
#  21.153764939983375,
#  21.466389059089124,
#  21.19499635149259,
#  21.292048803530633,
#  21.50754483192577,
#  21.393485648324713,
#  21.268872915767133,
#  21.476920244283974,
#  21.427935169194825,
#  21.178359544021077,
#  21.390083425678313,
#  21.33709222287871,
#  21.302375508472323,
#  21.408499545766972,
#  21.494891171867494,
#  21.233600527513772,
#  21.443672135239467,
#  21.356165236560628,
#  21.398201963311294,
#  21.349493943387643,
#  21.50199662311934,
#  21.38682677038014,
#  21.317156249657273,
#  21.440877771936357,
#  21.353047276148573,
#  21.29870087839663,
#  21.36037950962782,
#  21.161373667884618,
#  21.437461616376822,
#  21.33605515700765,
#  21.325526188127697,
#  21.345982965780422,
#  21.287572648376226,
#  21.412777139717946,
#  21.375217762077227,
#  21.513149735401385,
#  21.511570043687243,
#  21.318748611956835,
#  21.40290542319417,
#  21.323788782814518,
#  21.325198778882623,
#  21.39438320147019,
#  21.429898335190956,
#  21.387344223912805,
#  21.253284407313913,
#  21.328193562105298,
#  21.491676026606,
#  21.340141591383144,
#  21.286087665706873,
#  21.341597109101713,
#  21.488133171922527,
#  21.41244916850701,
#  21.2722853096202,
#  21.493219062977005,
#  21.511401301482692,
#  21.44978347606957,
#  21.4514499171637,
#  21.43934223218821,
#  21.360623098677024,
#  21.436989580048248,
#  21.418035534210503,
#  21.512820216361433,
#  21.514575279696146,
#  21.260995578952134,
#  21.404029158642516,
#  21.41654447610199,
#  21.213061906397343,
#  21.304788537323475,
#  21.319110641255975,
#  21.485274990438484,
#  21.491291777289007,
#  21.441091686487198,
#  21.289586702361703,
#  21.519393540962483,
#  21.28638892248273,
#  21.18184956186451,
#  21.377444459707476,
#  21.51642836618703,
#  21.51759890082758,
#  21.22163463011384,
#  21.45929869147949,
#  21.520258653785277,
#  21.468390112859197,
#  21.511710011138348,
#  21.470015451544896,
#  21.517208631383255,
#  21.47965809388552,
#  21.4123482699506,
#  21.44759586220607,
#  21.37103475368349,
#  21.49028120841831,
#  21.31104627996683,
#  21.429630808066577,
#  21.32386301085353,
#  21.389073455007747,
#  21.200433366233483,
#  21.15247137704864,
#  21.404380254331045,
#  21.480723532498814,
#  21.31764205847867,
#  21.465413772151805,
#  21.476406514644623,
#  21.487904545036145,
#  21.390862452448346,
#  21.458186310250312,
#  21.369181315996684,
#  21.42480815714225,
#  21.516124990055687,
#  21.351153342751786,
#  21.343890707124956,
#  21.37429880941636,
#  21.34620277583599,
#  21.51513165552751,
#  21.360294215381145,
#  21.40121544422982,
#  21.399490179799614,
#  21.444080324377865,
#  21.3990498764324,
#  21.38869426562451,
#  21.37721110507846,
#  21.392735570691002,
#  21.342023876029998,
#  21.385012943123,
#  21.249235664494336,
#  21.365359225077555,
#  21.14963040361181,
#  21.379542416063487,
#  21.299190292134877,
#  21.328717024065554,
#  21.421725664520636,
#  21.421760208904743,
#  21.395323911736334,
#  21.475265623070264,
#  21.3892228733748,
#  21.382837530371027,
#  21.492253911856075,
#  21.340126615483314,
#  21.38849919560016,
#  21.28440236952156,
#  21.434000573535737,
#  21.424484491813928,
#  21.408802146936047,
#  21.255637076683342,
#  21.462345806416124,
#  21.39783939809419,
#  21.26726417522877,
#  21.49772034474881,
#  21.43432602210669,
#  21.237732283538207,
#  21.378487144247625,
#  21.21008021850139,
#  21.497725568187885,
#  21.39024516742211,
#  21.365698341978714,
#  21.457628252217543,
#  21.382017539814072,
#  21.41392779024317,
#  21.24136492353864,
#  21.431849408647377,
#  21.417293081802185,
#  21.397665499243864,
#  21.424427875841467,
#  21.20240338752044,
#  21.49763532204088,
#  21.36824385484215,
#  21.244860213715583,
#  21.484346340643242,
#  21.239714936353266,
#  21.408897946123034,
#  21.361273613991216,
#  21.32087003486231,
#  21.424013359006494,
#  21.422229670919478,
#  21.34361807652749,
#  21.459328934084624,
#  21.484989726450294,
#  21.45543220243416,
#  21.160009643645026,
#  21.416370653838385,
#  21.380718946660636,
#  21.314030431443825,
#  21.473056759801693,
#  21.42398919313564,
#  21.305252979509532,
#  21.33224252355285,
#  21.51264981512213,
#  21.437609003158286,
#  21.212863680906594,
#  21.344693440012616,
#  21.146933796582736,
#  21.399454811471514,
#  21.44963648449628,
#  21.44387766020372,
#  21.395530374371447]

# %%
arr = uniform_filter1d(rewards, size=50)

# %%
x = []
y = []
for i,e in enumerate(arr):
    y.append(i)
    x.append(e)

# %%
plt.plot(y, x)#20% bias correction, medium-high prioritization rates(40%), proportional prioritization

# %%
print(env.action_space.low)   # [0. 0. 0. 0.]
print(env.action_space.high)  # [1. 1. 1. 1.]
# Out:
# [0. 0. 0. 0.]
# [1. 1. 1. 1.]

# %%
test_state = torch.zeros(1, 16).float().to("cpu")
test_state[0, 2] = 0.8
test_state[0, 14] = 1.0
test_state[0, 15] = 0.2
good_action = torch.tensor([[0.6, 0.6, 0.6, 0.6]]).float().to("cpu")
bad_action  = torch.tensor([[0.3, 0.3, 0.3, 0.3]]).float().to("cpu")

for net, name in [(a, "oqa"), (b, "oqb")]:
    net.eval()
    print(f"{name} Q(good): {net(test_state, good_action).item():.4f}")
    print(f"{name} Q(bad):  {net(test_state, bad_action).item():.4f}")
    net.train()
# Out:
# oqa Q(good): 47.9327
# oqa Q(bad):  47.9328
# oqb Q(good): 48.3837
# oqb Q(bad):  48.4034

# %%
real_state = torch.tensor(env.reset()[0]).float().unsqueeze(0).to("cpu")
good_action = torch.tensor([[0.6, 0.6, 0.6, 0.6]]).float().to("cpu")
bad_action  = torch.tensor([[0.3, 0.3, 0.3, 0.3]]).float().to("cpu")

for net, name in [(a, "oqa"), (b, "oqb")]:
    net.eval()
    print(f"{name} Q(good): {net(real_state, good_action).item():.4f}")
    print(f"{name} Q(bad):  {net(real_state, bad_action).item():.4f}")
    net.train()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[20], line 7
#       5 for net, name in [(a, "oqa"), (b, "oqb")]:
#       6     net.eval()
# ----> 7     print(f"{name} Q(good): {net(real_state, good_action).item():.4f}")
#       8     print(f"{name} Q(bad):  {net(real_state, bad_action).item():.4f}")
#       9     net.train()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1776, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1774     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775 else:
# -> 1776     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1787, in Module._call_impl(self, *args, **kwargs)
#    1782 # If we don't have any hooks, we want to skip the rest of the logic in
#    1783 # this function, and just call forward.
#    1784 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1785         or _global_backward_pre_hooks or _global_backward_hooks
#    1786         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787     return forward_call(*args, **kwargs)
#    1789 result = None
#    1790 called_always_called_hooks = set()
#
# Cell In[8], line 32, in FCQV.forward(self, state, action)
#      30     action = torch.tensor(action).float().to(self.device)
#      31 # x = torch.cat((state, action), dim=1)
# ---> 32 x = self.input_bn(state) # normalise state
#      33 x = F.leaky_relu(self.input_layer(x))
#      34 # x = self.input_bn(x)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1776, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1774     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775 else:
# -> 1776     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1787, in Module._call_impl(self, *args, **kwargs)
#    1782 # If we don't have any hooks, we want to skip the rest of the logic in
#    1783 # this function, and just call forward.
#    1784 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1785         or _global_backward_pre_hooks or _global_backward_hooks
#    1786         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787     return forward_call(*args, **kwargs)
#    1789 result = None
#    1790 called_always_called_hooks = set()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\batchnorm.py:194, in _BatchNorm.forward(self, input)
#     187     bn_training = (self.running_mean is None) and (self.running_var is None)
#     189 r"""
#     190 Buffers are only updated if they are to be tracked and we are in training mode. Thus they only need to be
#     191 passed when the update should occur (i.e. in training mode when they are tracked), or when buffer stats are
#     192 used for normalization (i.e. in eval mode when buffers are not None).
#     193 """
# --> 194 return F.batch_norm(
#     195     input,
#     196     # If buffers are not to be tracked, ensure that they won't be updated
#     197     (
#     198         self.running_mean
#     199         if not self.training or self.track_running_stats
#     200         else None
#     201     ),
#     202     self.running_var if not self.training or self.track_running_stats else None,
#     203     self.weight,
#     204     self.bias,
#     205     bn_training,
#     206     exponential_average_factor,
#     207     self.eps,
#     208 )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\functional.py:2846, in batch_norm(input, running_mean, running_var, weight, bias, training, momentum, eps)
#    2843 if eps <= 0.0:
#    2844     raise ValueError(f"batch_norm eps must be positive, but got {eps}")
# -> 2846 return torch.batch_norm(
#    2847     input,
#    2848     weight,
#    2849     bias,
#    2850     running_mean,
#    2851     running_var,
#    2852     training,
#    2853     momentum,
#    2854     eps,
#    2855     torch.backends.cudnn.enabled,
#    2856 )
#
# RuntimeError: running_mean should contain 16 elements not 20

# %%
env.close()

# %%
from env.drone_env import DRONE_MASS, GRAVITY, MAX_THRUST

hover_throttle = (DRONE_MASS * GRAVITY) / (4 * MAX_THRUST)
print(f"Hover throttle: {hover_throttle:.4f}")
# Out:
# Hover throttle: 0.5000
